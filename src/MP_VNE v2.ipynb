# %% [markdown]
# ### **Types**

# %%
from dataclasses import dataclass
from typing import List
import random

# %%
@dataclass
class PhysicalNode:
    internal_id: int
    external_id: int
    domain_id: int

    resource: float
    used_resource: float
    cost_per_unit: float
    delay: float

    @staticmethod
    def generator(external_id: int, internal_id: int, domain_id: int):
        return PhysicalNode(
            external_id=external_id,
            internal_id=internal_id,
            domain_id=domain_id,

            resource=random.uniform(100, 300),
            used_resource=0,
            cost_per_unit=random.uniform(1, 10),
            delay=random.uniform(1, 10)
        )

# %%
@dataclass
class PhysicalLink:
    src: PhysicalNode
    dest: PhysicalNode

    bandwidth: float
    used_bandwidth: float
    cost_per_unit: float
    delay: float

    @staticmethod
    def generator(source: PhysicalNode, dest: PhysicalNode):
        return PhysicalLink(
            src=source,
            dest=dest,
            bandwidth = random.uniform(1000, 3000),
            used_bandwidth=0,
            cost_per_unit = random.uniform(1, 10),
            delay = random.uniform(1, 10)
        )

# %%
import math
from dataclasses import dataclass, field
from typing import List, Optional

@dataclass
class PhysicalDomain:
    id: int
    nodes: List["PhysicalNode"]
    boundary_nodes: List["PhysicalNode"]
    intra_links: List[List[Optional["PhysicalLink"]]]
    inter_links: List["PhysicalLink"]

    dist: List[List[float]] = field(default_factory=list)
    next_node: List[List[Optional[int]]] = field(default_factory=list)

    @staticmethod
    def generator(num_of_nodes: int, number_of_boundary_nodes: int, domain_id: int, connection_rate: float):
        nodes = [
            PhysicalNode.generator(
                external_id=0,
                internal_id=i,
                domain_id=domain_id
            ) for i in range(num_of_nodes)
        ]
        
        intra_links = [[None for _ in range(num_of_nodes)] for _ in range(num_of_nodes)]

        for i in range(num_of_nodes):
            for j in range(i + 1, num_of_nodes):
                if random.random() <= connection_rate:
                    link = PhysicalLink.generator(nodes[i], nodes[j])
                    intra_links[i][j] = intra_links[j][i] = link

        boundary_nodes = random.choices(nodes, k=number_of_boundary_nodes)

        domain = PhysicalDomain(
            id=domain_id,
            nodes=nodes,
            boundary_nodes=boundary_nodes,
            intra_links=intra_links,
            inter_links=[]
        )

        domain.compute_shortest_paths()
        return domain

    def add_inter_links(self, link: "PhysicalLink"):
        self.inter_links.append(link)
    
    def calculate_weight(self, cost: float, delay: float):
        return 0.9*cost + 0.1*delay

    def compute_shortest_paths(self):
        n = len(self.nodes)
        self.dist = [[math.inf] * n for _ in range(n)]
        self.next_node = [[None] * n for _ in range(n)]

        for i in range(n):
            self.dist[i][i] = 0
            for j in range(n):
                link = self.intra_links[i][j]
                if link:
                    weight = self.calculate_weight(cost=link.cost_per_unit, delay=link.delay)
                    self.dist[i][j] = weight
                    self.next_node[i][j] = j

        for k in range(n):
            for i in range(n):
                for j in range(n):
                    if self.dist[i][k] + self.dist[k][j] < self.dist[i][j]:
                        self.dist[i][j] = self.dist[i][k] + self.dist[k][j]
                        self.next_node[i][j] = self.next_node[i][k]

    def shortest_path(self, src_id: int, dest_id: int):
        if not self.next_node or self.next_node[src_id][dest_id] is None:
            return []
        path = [src_id]
        while src_id != dest_id:
            src_id = self.next_node[src_id][dest_id]
            path.append(src_id)
        return path

    def shortest_distance(self, src_id: int, dest_id: int) -> float:
        if not self.dist:
            raise ValueError("Shortest paths not computed yet.")
        return self.dist[src_id][dest_id]

# %%
from dataclasses import dataclass
from typing import List
import random

@dataclass
class PhysicalNetwork:
    domains: List[PhysicalDomain]
    inter_links: List[PhysicalLink]

    @staticmethod
    def generator(num_domains: int, nodes_per_domain: int, boundary_nodes_per_domain: int, connection_rate: float):
        domains = []
        inter_links = []
        global_node_id = 0

        for domain_id in range(num_domains):
            domain = PhysicalDomain.generator(
                num_of_nodes=nodes_per_domain,
                number_of_boundary_nodes=boundary_nodes_per_domain,
                domain_id=domain_id,
                connection_rate=connection_rate
            )
            
            for node in domain.nodes:
                node.external_id = global_node_id
                global_node_id += 1

            domains.append(domain)

        for i in range(num_domains):
            for j in range(i + 1, num_domains):
                src = random.choice(domains[i].boundary_nodes)
                dest = random.choice(domains[j].boundary_nodes)

                link = PhysicalLink.generator(src, dest)
                inter_links.append(link)

                domains[i].add_inter_links(link)
                domains[j].add_inter_links(PhysicalLink(
                    src=link.dest,
                    dest=link.src,
                    bandwidth=link.bandwidth,
                    used_bandwidth=0,
                    cost_per_unit=link.cost_per_unit,
                    delay=link.delay
                ))

        return PhysicalNetwork(
            domains=domains,
            inter_links=inter_links
        )

# %%
@dataclass
class VirtualNode:
    id: int
    resource: float
    candidate_domains: List[int]

    @staticmethod
    def generator(node_id: int, num_candidates: int, num_domains: int):
        return VirtualNode(
            id=node_id,
            resource=random.uniform(1, 10),
            candidate_domains=random.sample(range(num_domains), k=num_candidates)
        )

# %%
@dataclass
class VirtualLink:
    src: VirtualNode
    dest: VirtualNode
    bandwidth: float

    @staticmethod
    def generator(src: VirtualNode, dest: VirtualNode):
        return VirtualLink(
            src=src,
            dest=dest,
            bandwidth=random.uniform(1, 10)
        )

# %%
from dataclasses import dataclass
from typing import List
import random

@dataclass
class VirtualNetwork:
    nodes: List[VirtualNode]
    links: List[List[VirtualLink]] 

    @staticmethod
    def generator(num_nodes: int, connection_rate: float, number_of_domains: int):
        nodes = [
            VirtualNode.generator(i, number_of_domains, number_of_domains)
            for i in range(num_nodes)
        ]

        links = [[None for _ in range(num_nodes)] for _ in range(num_nodes)]

        for i in range(num_nodes):
            for j in range(i + 1, num_nodes):
                if random.random() <= connection_rate:
                    links[i][j] = VirtualLink.generator(nodes[i], nodes[j])
                    links[j][i] = VirtualLink(
                        src=nodes[j],
                        dest=nodes[i],
                        bandwidth=links[i][j].bandwidth
                    )

        return VirtualNetwork(
            nodes=nodes,
            links=links
        )

# %%
import math
from typing import Dict, List, Tuple

class PhysicalNetworkEvaluator:
    def __init__(self, physical_network: PhysicalNetwork):
        self.physical_network = physical_network
        self.dist = None
        self.next_node = None
        self.network: List[List[PhysicalLink]] = None
        self.floy_d_shortest_path()

    def _get_all_nodes(self):
        return [n for d in self.physical_network.domains for n in d.nodes]

    def _build_global_graph(self):
        all_nodes = self._get_all_nodes()
        n = len(all_nodes)
        dist = [[math.inf] * n for _ in range(n)]
        next_node = [[None] * n for _ in range(n)]
        network:List[List[PhysicalLink]] = [[None]*n for _ in range(n)]

        for i in range(n):
            dist[i][i] = 0

        def add_link(link: PhysicalLink):
            u = link.src.external_id
            v = link.dest.external_id
            w = link.cost_per_unit
            network[u][v] = network[v][u] = link

            if w < dist[u][v]:
                dist[u][v] = dist[v][u] = w
                next_node[u][v] = v
                next_node[v][u] = u

        for d in self.physical_network.domains:
            for row in d.intra_links:
                for link in row:
                    if link:
                        add_link(link)

        for link in self.physical_network.inter_links:
            add_link(link)

        self.dist, self.next_node, self.network = dist, next_node, network

    def floy_d_shortest_path(self):
        if self.dist is None:
            self._build_global_graph()

        n = len(self.dist)
        for k in range(n):
            for i in range(n):
                if self.dist[i][k] == math.inf:
                    continue
                for j in range(n):
                    nd = self.dist[i][k] + self.dist[k][j]
                    if nd < self.dist[i][j]:
                        self.dist[i][j] = nd
                        self.next_node[i][j] = self.next_node[i][k]

    def get_distance(self, src, dest) -> float:
        return self.dist[src.external_id][dest.external_id]

    def get_path(self, src, dest):
        i, j = src.external_id, dest.external_id
        if self.next_node[i][j] is None:
            return []
        path = [src]
        while i != j:
            i = self.next_node[i][j]
            node = self._get_all_nodes()[i]
            path.append(node)
        return path
    
    # Return [cost, delay] id valid, if not return None
    def evaluate_mapping_cost(self, mapping: Dict[int, PhysicalNode], v_network: VirtualNetwork) -> Tuple[float, float] | None:
        total_delay = 0.0
        total_cost = 0.0
        for i in range(len(v_network.nodes)):
            v_src = v_network.nodes[i]
            p_src = mapping[i]

            if v_src.resource > p_src.resource:
                return None

            total_cost += v_src.resource * p_src.cost_per_unit
            total_delay += p_src.delay

            for j in range(i+1, len(v_network.nodes)):
                v_link = v_network.links[i][j]
                if not v_link:
                    continue
                
                p_dst = mapping[j]
                shortest_path:List[PhysicalNode] = self.get_path(p_src, p_dst)

                prev_node = None
                for node in shortest_path:
                    if prev_node:
                        p_link = self.network[prev_node.external_id][node.external_id]
                        remaining_bandwidth = p_link.bandwidth - p_link.used_bandwidth
                        if remaining_bandwidth < v_link.bandwidth:
                            return None

                        total_cost += v_link.bandwidth * p_link.cost_per_unit
                        total_delay += p_link.delay

                    prev_node = node

        return total_delay, total_cost

# %% [markdown]
# ### **Visualization**

# %%
import networkx as nx
import matplotlib.pyplot as plt

def visualize_physical_network(network: PhysicalNetwork):
    G = nx.Graph()

    for domain in network.domains:
        for node in domain.nodes:
            G.add_node(
                node.external_id,
                domain=domain.id,
                resource=node.resource,
                cost=node.cost_per_unit,
                delay=node.delay,
            )

    for domain in network.domains:
        for row in domain.intra_links:
            for link in row:
                if link:
                    G.add_edge(
                        link.src.external_id,
                        link.dest.external_id,
                        bandwidth=link.bandwidth,
                        type="intra"
                    )

    for link in network.inter_links:
        G.add_edge(
            link.src.external_id,
            link.dest.external_id,
            bandwidth=link.bandwidth,
            type="inter"
        )

    pos = nx.spring_layout(G, seed=42, k=1.5, iterations=200)
    plt.figure(figsize=(12, 9))

    domain_colors = {d.id: f"C{d.id % 10}" for d in network.domains}

    for domain in network.domains:
        nodes = [n.external_id for n in domain.nodes]
        nx.draw_networkx_nodes(
            G,
            pos,
            nodelist=nodes,
            node_color=domain_colors[domain.id],
            label=f"Domain {domain.id}",
            node_size=700
        )

    intra_edges = [(u, v) for u, v, d in G.edges(data=True) if d["type"] == "intra"]
    inter_edges = [(u, v) for u, v, d in G.edges(data=True) if d["type"] == "inter"]

    nx.draw_networkx_edges(G, pos, edgelist=intra_edges, style="solid", width=1.5, alpha=0.8)
    nx.draw_networkx_edges(G, pos, edgelist=inter_edges, style="dotted", width=2.2, edge_color="black")

    node_labels = {
        n: f"{n}\n({d['resource']:.1f})"
        for n, d in G.nodes(data=True)
    }
    nx.draw_networkx_labels(G, pos, labels=node_labels, font_size=9)

    edge_labels = {
        (u, v): f"{d['bandwidth']:.1f}"
        for u, v, d in G.edges(data=True)
    }
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=8)

    plt.title("Physical Network Visualization")
    plt.legend()
    plt.axis("off")
    plt.tight_layout()
    plt.show()

# %%
def visualize_virtual_network(virtual_network):
    import networkx as nx
    import matplotlib.pyplot as plt

    G = nx.Graph()
    for node in virtual_network.nodes:
        G.add_node(node.id, resource=node.resource)

    for i in range(len(virtual_network.nodes)):
        for j in range(i + 1, len(virtual_network.nodes)):
            link = virtual_network.links[i][j]
            if link:
                G.add_edge(link.src.id, link.dest.id, bandwidth=link.bandwidth)

    pos = nx.spring_layout(G, seed=42, k=1.2, iterations=150)

    node_labels = {
        n: f"{n}\n({d['resource']:.1f})"
        for n, d in G.nodes(data=True)
    }

    edge_labels = {
        (u, v): f"{d['bandwidth']:.1f}"
        for u, v, d in G.edges(data=True)
    }

    plt.figure(figsize=(7, 6))
    nx.draw(
        G,
        pos,
        with_labels=False,
        node_color='skyblue',
        node_size=800,
        edge_color='gray',
        width=1.5
    )
    nx.draw_networkx_labels(G, pos, labels=node_labels, font_size=9)
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=8)

    plt.title("Virtual Network Visualization")
    plt.axis("off")
    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt
def visualize_array(arr, title, x, y):
    plt.plot(arr, marker='o')
    plt.title(title)
    plt.xlabel(x)
    plt.ylabel(y)
    plt.grid(True)
    plt.show()

# %% [markdown]
# ### **MP_VNE**

# %%
import random
import math
import numpy as np

class MP_VNE:
    def __init__(self, physical_network: PhysicalNetwork):
        self.physical_network = physical_network
        self.evaluator = PhysicalNetworkEvaluator(physical_network=physical_network)

    def select_candidate_nodes(self, v_network: VirtualNetwork) -> List[List[PhysicalNode]]:
        candidate_nodes = [[] for _ in range(len(v_network.nodes))]

        for v_node in v_network.nodes:
            valid_domains = [
                d for d in self.physical_network.domains
                if d.id in v_node.candidate_domains
            ]

            for domain in valid_domains:
                for p_node in domain.nodes:
                    if p_node.resource - p_node.used_resource >= v_node.resource:
                        candidate_nodes[v_node.id].append(p_node)

        return candidate_nodes

    def compute_ckb(self, p_node: PhysicalNode, dest_pnode: PhysicalNode):
        domain_dict = {d.id: d for d in self.physical_network.domains}
        src_domain = domain_dict[p_node.domain_id]

        dest_domain_id=dest_pnode.domain_id
        dest_domain = domain_dict[dest_domain_id]

        if src_domain.id == dest_domain.id:
            return src_domain.shortest_distance(p_node.internal_id, dest_pnode.internal_id)

        boundary_nodes = [
            link.src for link in src_domain.inter_links
            if (link.dest.domain_id == dest_domain.id)
        ]

        if not boundary_nodes or not len(boundary_nodes):
            boundary_nodes = src_domain.boundary_nodes

        if boundary_nodes:
            link_cost = 0
            for b_node in boundary_nodes:
                path_cost = src_domain.shortest_distance(p_node.internal_id, b_node.internal_id)
                link_cost += path_cost
            return link_cost / len(boundary_nodes)

        return math.inf


    def predict_mapping_cost(self, v_network: VirtualNetwork, mapping: List[int], candidate_nodes: List[List[PhysicalNode]]):
        total_cpu_cost = 0
        total_link_cost = 0

        for v_node in v_network.nodes:
            candidate_index = mapping[v_node.id]
            try:
                p_node = candidate_nodes[v_node.id][candidate_index]
            except Exception as err:
                print(candidate_index, len(candidate_nodes[v_node.id]), err)
            cpu_v = v_node.resource

            cost_cpu = cpu_v * p_node.cost_per_unit
            link_cost = 0

            neighbor_links = []
            for j in range(len(v_network.nodes)):
                link = v_network.links[v_node.id][j]
                if link:
                    neighbor_links.append(link)

            for link in neighbor_links:
                bw = link.bandwidth
                dest_vnode = link.dest

                dest_pnode = candidate_nodes[dest_vnode.id][0]
                c_kb = self.compute_ckb(p_node, dest_pnode)
                link_cost += bw * c_kb

            if len(neighbor_links) > 0:
                total_link_cost += link_cost / len(neighbor_links)

            total_cpu_cost += cost_cpu

        return total_cpu_cost + total_link_cost 
    @staticmethod
    def minus_operation(a, b):
        arr_a = np.array(a)
        arr_b = np.array(b)
        
        return (arr_a != arr_b).astype(int)

    @staticmethod
    def add_operation(a, b):
        return a + b
    
    def optimize_mapping(self, v_network: VirtualNetwork, candidate_nodes: List[List[PhysicalNode]], num_particles=10, max_iter=30) -> List[PhysicalNode]:
        c1 = 0.3
        c2 = 0.3
        mutation_prob = 0.4
        v_nodes_list = list(v_network.nodes)
        num_v_nodes = len(v_nodes_list)

        particles_list = []
        for _ in range(num_particles):
            mapping = [random.randint(0, len(candidate_nodes[v.id]) - 1) for v in v_nodes_list]
            particles_list.append(mapping)
        
        particles = np.array(particles_list)
        best_particles = particles.copy()
        
        v = np.zeros((num_particles, num_v_nodes))

        best_costs = np.array([
            self.predict_mapping_cost(v_network, particles[i], candidate_nodes) 
            for i in range(num_particles)
        ])

        global_best_idx = np.argmin(best_costs)
        global_best = best_particles[global_best_idx].copy()
        
        for _ in range(max_iter):
            r1 = np.random.rand(num_particles, 1)
            r2 = np.random.rand(num_particles, 1)

            diff_local = MP_VNE.minus_operation(best_particles, particles)
            diff_global = MP_VNE.minus_operation(global_best, particles)

            v = v + (c1 * r1 * diff_local) + (c2 * r2 * diff_global)
            
            for i in range(num_particles):
                particles[i] = MP_VNE.add_operation(particles[i], v[i])
                for j in range(num_v_nodes):
                    particles[i][j] = particles[i][j] % len(candidate_nodes[j])

                if random.random() < mutation_prob:
                    v_node_idx = random.randint(0, num_v_nodes - 1)
                    particles[i, v_node_idx] = global_best[v_node_idx]

            current_costs = np.array([
                self.predict_mapping_cost(v_network, particles[i], candidate_nodes) 
                for i in range(num_particles)
            ])
            
            update_mask = current_costs < best_costs
            
            best_costs[update_mask] = current_costs[update_mask]
            best_particles[update_mask] = particles[update_mask]

            best_idx = np.argmin(best_costs)
            global_best = best_particles[best_idx].copy()
            
        return [candidate_nodes[i][global_best[i]] for i in range(num_v_nodes)]

    def construct_mapping_request(self, v_network: VirtualNetwork, best_mapping):
        mapping_request = []
        for v_node in v_network.nodes:
            p_node = best_mapping[v_node.id]
            mapping_request.append({
                "v_node": v_node.id,
                "p_node": p_node.internal_id,
                "domain": p_node.domain_id,
                "resource_req": v_node.resource
            })
        return mapping_request

    def map(self, v_network: VirtualNetwork, best_mapping: List[int]):
        for src_vnode in v_network.nodes:
            src_pnode = best_mapping[src_vnode.id]
            # src_pnode.used_resource += src_vnode.resource

            for dest_vnode in v_network.nodes:
                v_link = v_network.links[src_vnode.id][dest_vnode.id]
                if v_link == None:
                    continue
                
                dest_pnode = best_mapping[dest_vnode.id]

                if dest_pnode.domain_id != src_pnode.domain_id:
                   continue

                physical_domain_id:int = src_pnode.domain_id
                physical_domain = self.physical_network.domains[physical_domain_id]
                nodes_on_path = physical_domain.shortest_path(src_pnode.internal_id, dest_pnode.internal_id)

                # prev_node = None
                # for node in nodes_on_path:
                #     if prev_node:
                #         path = physical_domain.intra_links[prev_node][node]
                #         path.used_bandwidth += v_link.bandwidth
                    
                #     prev_node = node

    def run(self, v_network: VirtualNetwork):
        candidate_nodes = self.select_candidate_nodes(v_network)

        if [] in candidate_nodes:
            return None

        best_mapping = self.optimize_mapping(v_network, candidate_nodes, 50)
        self.map(v_network, best_mapping)
        return best_mapping

# %% [markdown]
# ### **Experiment**

# %% [markdown]
# **Parametters**

# %%
# For network configuration
number_of_physical_network_domain = 4
number_of_nodes = 30
# node_resource_quantity = "U[100, 300]"
# node_cost = "U[1, 10]"
# node_delay = "U[1, 10]"
# link_resources = "U[1000, 3000]"
# link_cost = "U[1, 10]"
# link_delay = "U[1, 10]"
number_of_boundary_nodes = 2 # 
link_connection_rate = 0.7

# For request
number_of_request_nodes = 6
# CPU_requirements = "U[1, 10]"
# bandwidth_requirements = "U[1, 10]"

INFINITY=1e9
number_of_created_node = 0

# %% [markdown]
# **Data**

# %%
# Generate network
p_network = PhysicalNetwork.generator(
                num_domains=number_of_physical_network_domain, 
                nodes_per_domain=8,
                boundary_nodes_per_domain=2, 
                connection_rate=link_connection_rate
            )

visualize_physical_network(p_network)

# %% [markdown]
# **Algorithm Execution**

# %%
mpvne = MP_VNE(p_network)

number_of_batch = 100
num_of_request_per_batch = 50

total_request = 0
accept_request = 0
costs = []
delays = []
acceptance_rates = []

reason = [0, 0, 0]

for batch in range(number_of_batch):
    avg_cost = []
    avg_delay = []
    for request in range(num_of_request_per_batch):
        total_request += 1

        v_network = VirtualNetwork.generator(
                        num_nodes=number_of_request_nodes, 
                        connection_rate=0.5, 
                        number_of_domains=number_of_physical_network_domain
                    )

        best_mapping = mpvne.run(v_network)
        if not best_mapping:
            reason[0] += 1

        if best_mapping: # PSO found solution
            evaluator = PhysicalNetworkEvaluator(physical_network=p_network)
            mapping_cost = evaluator.evaluate_mapping_cost(best_mapping, v_network)
            if mapping_cost: # valid solution
                cost, delay = mapping_cost

                avg_cost.append(cost)
                avg_delay.append(delay)

                accept_request += 1
                acceptance_rate = accept_request / total_request
                acceptance_rates.append(acceptance_rate)
                print(f"Request {total_request} \t: Total cost: {cost:.3f} \t Total delay: {delay:.3f} \t Acceptance rate: {acceptance_rate:.3f}")
                continue
            else:
                reason[1] += 1
        acceptance_rate = accept_request / total_request
        print(f"Request {total_request} \t: Total cost: inf \t Total delay: inf \t Acceptance rate: {acceptance_rate:.3f}")

    costs.append(np.average(avg_cost))
    delays.append(np.average(avg_delay))
    acceptance_rates.append(acceptance_rate)
# Out:
# Request 1 	: Total cost: 112.919 	 Total delay: 196.091 	 Acceptance rate: 1.000
# Request 2 	: Total cost: 148.560 	 Total delay: 349.119 	 Acceptance rate: 1.000
# Request 3 	: Total cost: 128.386 	 Total delay: 242.577 	 Acceptance rate: 1.000
# Request 4 	: Total cost: 157.721 	 Total delay: 308.322 	 Acceptance rate: 1.000
# Request 5 	: Total cost: 94.712 	 Total delay: 278.777 	 Acceptance rate: 1.000
# Request 6 	: Total cost: 133.083 	 Total delay: 226.065 	 Acceptance rate: 1.000
# Request 7 	: Total cost: 86.278 	 Total delay: 182.887 	 Acceptance rate: 1.000
# Request 8 	: Total cost: 101.091 	 Total delay: 249.246 	 Acceptance rate: 1.000
# Request 9 	: Total cost: 118.062 	 Total delay: 254.245 	 Acceptance rate: 1.000
# Request 10 	: Total cost: 107.347 	 Total delay: 504.377 	 Acceptance rate: 1.000
# Request 11 	: Total cost: 77.839 	 Total delay: 263.734 	 Acceptance rate: 1.000
# Request 12 	: Total cost: 178.174 	 Total delay: 317.252 	 Acceptance rate: 1.000
# Request 13 	: Total cost: 90.900 	 Total delay: 169.114 	 Acceptance rate: 1.000
# Request 14 	: Total cost: 150.344 	 Total delay: 322.595 	 Acceptance rate: 1.000
# Request 15 	: Total cost: 68.649 	 Total delay: 136.492 	 Acceptance rate: 1.000
# Request 16 	: Total cost: 124.769 	 Total delay: 302.750 	 Acceptance rate: 1.000
# Request 17 	: Total cost: 186.177 	 Total delay: 382.423 	 Acceptance rate: 1.000
# Request 18 	: Total cost: 153.190 	 Total delay: 346.925 	 Acceptance rate: 1.000
# Request 19 	: Total cost: 155.924 	 Total delay: 215.738 	 Acceptance rate: 1.000
# Request 20 	: Total cost: 117.582 	 Total delay: 283.256 	 Acceptance rate: 1.000
# Request 21 	: Total cost: 118.384 	 Total delay: 276.723 	 Acceptance rate: 1.000
# Request 22 	: Total cost: 54.676 	 Total delay: 143.796 	 Acceptance rate: 1.000
# Request 23 	: Total cost: 53.909 	 Total delay: 52.686 	 Acceptance rate: 1.000
# Request 24 	: Total cost: 126.186 	 Total delay: 334.966 	 Acceptance rate: 1.000
# Request 25 	: Total cost: 112.513 	 Total delay: 232.038 	 Acceptance rate: 1.000
# Request 26 	: Total cost: 109.534 	 Total delay: 222.328 	 Acceptance rate: 1.000
# Request 27 	: Total cost: 124.299 	 Total delay: 452.228 	 Acceptance rate: 1.000
# Request 28 	: Total cost: 94.189 	 Total delay: 276.826 	 Acceptance rate: 1.000
# Request 29 	: Total cost: 129.360 	 Total delay: 191.486 	 Acceptance rate: 1.000
# Request 30 	: Total cost: 108.869 	 Total delay: 279.782 	 Acceptance rate: 1.000
# Request 31 	: Total cost: 126.861 	 Total delay: 357.399 	 Acceptance rate: 1.000
# Request 32 	: Total cost: 131.240 	 Total delay: 299.361 	 Acceptance rate: 1.000
# Request 33 	: Total cost: 101.105 	 Total delay: 225.134 	 Acceptance rate: 1.000
# Request 34 	: Total cost: 151.602 	 Total delay: 222.348 	 Acceptance rate: 1.000
# Request 35 	: Total cost: 117.844 	 Total delay: 299.694 	 Acceptance rate: 1.000
# Request 36 	: Total cost: 91.155 	 Total delay: 178.001 	 Acceptance rate: 1.000
# Request 37 	: Total cost: 71.527 	 Total delay: 80.659 	 Acceptance rate: 1.000
# Request 38 	: Total cost: 102.671 	 Total delay: 172.022 	 Acceptance rate: 1.000
# Request 39 	: Total cost: 84.744 	 Total delay: 295.515 	 Acceptance rate: 1.000
# Request 40 	: Total cost: 80.504 	 Total delay: 302.942 	 Acceptance rate: 1.000
# Request 41 	: Total cost: 63.481 	 Total delay: 113.717 	 Acceptance rate: 1.000
# Request 42 	: Total cost: 87.854 	 Total delay: 199.960 	 Acceptance rate: 1.000
# Request 43 	: Total cost: 74.853 	 Total delay: 106.166 	 Acceptance rate: 1.000
# Request 44 	: Total cost: 93.287 	 Total delay: 111.669 	 Acceptance rate: 1.000
# Request 45 	: Total cost: 100.896 	 Total delay: 237.919 	 Acceptance rate: 1.000
# Request 46 	: Total cost: 179.305 	 Total delay: 431.614 	 Acceptance rate: 1.000
# Request 47 	: Total cost: 78.472 	 Total delay: 244.969 	 Acceptance rate: 1.000
# Request 48 	: Total cost: 91.812 	 Total delay: 200.726 	 Acceptance rate: 1.000
# Request 49 	: Total cost: 105.670 	 Total delay: 147.040 	 Acceptance rate: 1.000
# Request 50 	: Total cost: 80.072 	 Total delay: 102.964 	 Acceptance rate: 1.000
# Request 51 	: Total cost: 100.039 	 Total delay: 238.214 	 Acceptance rate: 1.000
# Request 52 	: Total cost: 103.002 	 Total delay: 126.839 	 Acceptance rate: 1.000
# Request 53 	: Total cost: 90.981 	 Total delay: 155.017 	 Acceptance rate: 1.000
# Request 54 	: Total cost: 87.055 	 Total delay: 249.689 	 Acceptance rate: 1.000
# Request 55 	: Total cost: 120.599 	 Total delay: 283.890 	 Acceptance rate: 1.000
# Request 56 	: Total cost: 94.889 	 Total delay: 163.495 	 Acceptance rate: 1.000
# Request 57 	: Total cost: 121.277 	 Total delay: 396.898 	 Acceptance rate: 1.000
# Request 58 	: Total cost: 105.233 	 Total delay: 316.528 	 Acceptance rate: 1.000
# Request 59 	: Total cost: 96.797 	 Total delay: 155.839 	 Acceptance rate: 1.000
# Request 60 	: Total cost: 88.889 	 Total delay: 231.994 	 Acceptance rate: 1.000
# Request 61 	: Total cost: 83.631 	 Total delay: 200.144 	 Acceptance rate: 1.000
# Request 62 	: Total cost: 88.549 	 Total delay: 126.521 	 Acceptance rate: 1.000
# Request 63 	: Total cost: 86.725 	 Total delay: 134.890 	 Acceptance rate: 1.000
# Request 64 	: Total cost: 60.132 	 Total delay: 135.549 	 Acceptance rate: 1.000
# Request 65 	: Total cost: 60.141 	 Total delay: 140.050 	 Acceptance rate: 1.000
# Request 66 	: Total cost: 63.154 	 Total delay: 140.612 	 Acceptance rate: 1.000
# Request 67 	: Total cost: 147.700 	 Total delay: 278.685 	 Acceptance rate: 1.000
# Request 68 	: Total cost: 95.860 	 Total delay: 179.469 	 Acceptance rate: 1.000
# Request 69 	: Total cost: 86.401 	 Total delay: 188.345 	 Acceptance rate: 1.000
# Request 70 	: Total cost: 95.174 	 Total delay: 189.374 	 Acceptance rate: 1.000
# Request 71 	: Total cost: 118.893 	 Total delay: 163.911 	 Acceptance rate: 1.000
# Request 72 	: Total cost: 149.201 	 Total delay: 390.251 	 Acceptance rate: 1.000
# Request 73 	: Total cost: 116.380 	 Total delay: 264.807 	 Acceptance rate: 1.000
# Request 74 	: Total cost: 114.334 	 Total delay: 353.986 	 Acceptance rate: 1.000
# Request 75 	: Total cost: 95.397 	 Total delay: 70.337 	 Acceptance rate: 1.000
# Request 76 	: Total cost: 56.154 	 Total delay: 101.940 	 Acceptance rate: 1.000
# Request 77 	: Total cost: 76.303 	 Total delay: 174.148 	 Acceptance rate: 1.000
# Request 78 	: Total cost: 194.868 	 Total delay: 237.822 	 Acceptance rate: 1.000
# Request 79 	: Total cost: 91.186 	 Total delay: 166.582 	 Acceptance rate: 1.000
# Request 80 	: Total cost: 95.496 	 Total delay: 383.614 	 Acceptance rate: 1.000
# Request 81 	: Total cost: 86.822 	 Total delay: 168.189 	 Acceptance rate: 1.000
# Request 82 	: Total cost: 102.063 	 Total delay: 281.438 	 Acceptance rate: 1.000
# Request 83 	: Total cost: 154.853 	 Total delay: 309.040 	 Acceptance rate: 1.000
# Request 84 	: Total cost: 100.747 	 Total delay: 191.759 	 Acceptance rate: 1.000
# Request 85 	: Total cost: 90.309 	 Total delay: 154.840 	 Acceptance rate: 1.000
# Request 86 	: Total cost: 102.038 	 Total delay: 219.539 	 Acceptance rate: 1.000
# Request 87 	: Total cost: 66.372 	 Total delay: 98.329 	 Acceptance rate: 1.000
# Request 88 	: Total cost: 112.307 	 Total delay: 214.848 	 Acceptance rate: 1.000
# Request 89 	: Total cost: 69.767 	 Total delay: 152.126 	 Acceptance rate: 1.000
# Request 90 	: Total cost: 74.399 	 Total delay: 156.853 	 Acceptance rate: 1.000
# Request 91 	: Total cost: 104.603 	 Total delay: 178.546 	 Acceptance rate: 1.000
# Request 92 	: Total cost: 79.269 	 Total delay: 169.838 	 Acceptance rate: 1.000
# Request 93 	: Total cost: 67.676 	 Total delay: 115.226 	 Acceptance rate: 1.000
# Request 94 	: Total cost: 126.758 	 Total delay: 372.117 	 Acceptance rate: 1.000
# Request 95 	: Total cost: 96.124 	 Total delay: 276.805 	 Acceptance rate: 1.000
# Request 96 	: Total cost: 95.526 	 Total delay: 147.712 	 Acceptance rate: 1.000
# Request 97 	: Total cost: 116.691 	 Total delay: 304.599 	 Acceptance rate: 1.000
# Request 98 	: Total cost: 132.947 	 Total delay: 398.316 	 Acceptance rate: 1.000
# Request 99 	: Total cost: 79.975 	 Total delay: 124.631 	 Acceptance rate: 1.000
# Request 100 	: Total cost: 80.202 	 Total delay: 162.719 	 Acceptance rate: 1.000
# Request 101 	: Total cost: 129.357 	 Total delay: 413.660 	 Acceptance rate: 1.000
# Request 102 	: Total cost: 82.869 	 Total delay: 102.591 	 Acceptance rate: 1.000
# Request 103 	: Total cost: 92.217 	 Total delay: 211.044 	 Acceptance rate: 1.000
# Request 104 	: Total cost: 61.469 	 Total delay: 69.266 	 Acceptance rate: 1.000
# Request 105 	: Total cost: 101.336 	 Total delay: 234.071 	 Acceptance rate: 1.000
# Request 106 	: Total cost: 118.687 	 Total delay: 189.367 	 Acceptance rate: 1.000
# Request 107 	: Total cost: 127.504 	 Total delay: 179.725 	 Acceptance rate: 1.000
# Request 108 	: Total cost: 104.792 	 Total delay: 324.895 	 Acceptance rate: 1.000
# Request 109 	: Total cost: 86.697 	 Total delay: 90.590 	 Acceptance rate: 1.000
# Request 110 	: Total cost: 104.656 	 Total delay: 123.987 	 Acceptance rate: 1.000
# Request 111 	: Total cost: 106.289 	 Total delay: 320.682 	 Acceptance rate: 1.000
# Request 112 	: Total cost: 147.828 	 Total delay: 317.065 	 Acceptance rate: 1.000
# Request 113 	: Total cost: 97.267 	 Total delay: 154.558 	 Acceptance rate: 1.000
# Request 114 	: Total cost: 120.750 	 Total delay: 173.931 	 Acceptance rate: 1.000
# Request 115 	: Total cost: 106.043 	 Total delay: 249.412 	 Acceptance rate: 1.000
# Request 116 	: Total cost: 112.935 	 Total delay: 195.446 	 Acceptance rate: 1.000
# Request 117 	: Total cost: 116.207 	 Total delay: 169.010 	 Acceptance rate: 1.000
# Request 118 	: Total cost: 129.039 	 Total delay: 395.183 	 Acceptance rate: 1.000
# Request 119 	: Total cost: 137.693 	 Total delay: 403.814 	 Acceptance rate: 1.000
# Request 120 	: Total cost: 105.025 	 Total delay: 332.364 	 Acceptance rate: 1.000
# Request 121 	: Total cost: 140.113 	 Total delay: 364.697 	 Acceptance rate: 1.000
# Request 122 	: Total cost: 93.620 	 Total delay: 128.333 	 Acceptance rate: 1.000
# Request 123 	: Total cost: 96.915 	 Total delay: 295.076 	 Acceptance rate: 1.000
# Request 124 	: Total cost: 69.969 	 Total delay: 109.590 	 Acceptance rate: 1.000
# Request 125 	: Total cost: 98.185 	 Total delay: 234.721 	 Acceptance rate: 1.000
# Request 126 	: Total cost: 96.981 	 Total delay: 227.231 	 Acceptance rate: 1.000
# Request 127 	: Total cost: 110.486 	 Total delay: 389.030 	 Acceptance rate: 1.000
# Request 128 	: Total cost: 110.076 	 Total delay: 245.708 	 Acceptance rate: 1.000
# Request 129 	: Total cost: 121.714 	 Total delay: 359.877 	 Acceptance rate: 1.000
# Request 130 	: Total cost: 111.206 	 Total delay: 196.164 	 Acceptance rate: 1.000
# Request 131 	: Total cost: 87.026 	 Total delay: 242.958 	 Acceptance rate: 1.000
# Request 132 	: Total cost: 137.158 	 Total delay: 329.941 	 Acceptance rate: 1.000
# Request 133 	: Total cost: 85.485 	 Total delay: 278.436 	 Acceptance rate: 1.000
# Request 134 	: Total cost: 88.544 	 Total delay: 256.830 	 Acceptance rate: 1.000
# Request 135 	: Total cost: 107.916 	 Total delay: 300.869 	 Acceptance rate: 1.000
# Request 136 	: Total cost: 70.349 	 Total delay: 126.584 	 Acceptance rate: 1.000
# Request 137 	: Total cost: 92.384 	 Total delay: 192.623 	 Acceptance rate: 1.000
# Request 138 	: Total cost: 119.883 	 Total delay: 200.507 	 Acceptance rate: 1.000
# Request 139 	: Total cost: 83.165 	 Total delay: 212.322 	 Acceptance rate: 1.000
# Request 140 	: Total cost: 143.317 	 Total delay: 309.285 	 Acceptance rate: 1.000
# Request 141 	: Total cost: 127.536 	 Total delay: 451.712 	 Acceptance rate: 1.000
# Request 142 	: Total cost: 78.039 	 Total delay: 95.471 	 Acceptance rate: 1.000
# Request 143 	: Total cost: 104.945 	 Total delay: 135.297 	 Acceptance rate: 1.000
# Request 144 	: Total cost: 69.023 	 Total delay: 77.957 	 Acceptance rate: 1.000
# Request 145 	: Total cost: 97.592 	 Total delay: 152.475 	 Acceptance rate: 1.000
# Request 146 	: Total cost: 82.278 	 Total delay: 200.722 	 Acceptance rate: 1.000
# Request 147 	: Total cost: 166.214 	 Total delay: 316.364 	 Acceptance rate: 1.000
# Request 148 	: Total cost: 200.574 	 Total delay: 329.784 	 Acceptance rate: 1.000
# Request 149 	: Total cost: 70.750 	 Total delay: 144.801 	 Acceptance rate: 1.000
# Request 150 	: Total cost: 90.189 	 Total delay: 160.773 	 Acceptance rate: 1.000
# Request 151 	: Total cost: 114.414 	 Total delay: 136.247 	 Acceptance rate: 1.000
# Request 152 	: Total cost: 82.578 	 Total delay: 181.047 	 Acceptance rate: 1.000
# Request 153 	: Total cost: 105.195 	 Total delay: 221.887 	 Acceptance rate: 1.000
# Request 154 	: Total cost: 99.515 	 Total delay: 141.491 	 Acceptance rate: 1.000
# Request 155 	: Total cost: 90.222 	 Total delay: 113.612 	 Acceptance rate: 1.000
# Request 156 	: Total cost: 127.502 	 Total delay: 189.370 	 Acceptance rate: 1.000
# Request 157 	: Total cost: 84.479 	 Total delay: 135.366 	 Acceptance rate: 1.000
# Request 158 	: Total cost: 151.076 	 Total delay: 273.000 	 Acceptance rate: 1.000
# Request 159 	: Total cost: 84.641 	 Total delay: 147.777 	 Acceptance rate: 1.000
# Request 160 	: Total cost: 122.558 	 Total delay: 234.112 	 Acceptance rate: 1.000
# Request 161 	: Total cost: 76.142 	 Total delay: 166.151 	 Acceptance rate: 1.000
# Request 162 	: Total cost: 107.005 	 Total delay: 353.776 	 Acceptance rate: 1.000
# Request 163 	: Total cost: 86.218 	 Total delay: 154.605 	 Acceptance rate: 1.000
# Request 164 	: Total cost: 112.647 	 Total delay: 194.318 	 Acceptance rate: 1.000
# Request 165 	: Total cost: 160.387 	 Total delay: 302.707 	 Acceptance rate: 1.000
# Request 166 	: Total cost: 85.453 	 Total delay: 169.624 	 Acceptance rate: 1.000
# Request 167 	: Total cost: 97.608 	 Total delay: 111.663 	 Acceptance rate: 1.000
# Request 168 	: Total cost: 77.345 	 Total delay: 205.679 	 Acceptance rate: 1.000
# Request 169 	: Total cost: 107.367 	 Total delay: 166.434 	 Acceptance rate: 1.000
# Request 170 	: Total cost: 121.084 	 Total delay: 336.029 	 Acceptance rate: 1.000
# Request 171 	: Total cost: 120.796 	 Total delay: 224.811 	 Acceptance rate: 1.000
# Request 172 	: Total cost: 134.032 	 Total delay: 319.978 	 Acceptance rate: 1.000
# Request 173 	: Total cost: 97.608 	 Total delay: 161.656 	 Acceptance rate: 1.000
# Request 174 	: Total cost: 89.888 	 Total delay: 119.954 	 Acceptance rate: 1.000
# Request 175 	: Total cost: 81.799 	 Total delay: 131.869 	 Acceptance rate: 1.000
# Request 176 	: Total cost: 140.958 	 Total delay: 313.858 	 Acceptance rate: 1.000
# Request 177 	: Total cost: 108.104 	 Total delay: 350.893 	 Acceptance rate: 1.000
# Request 178 	: Total cost: 124.547 	 Total delay: 164.064 	 Acceptance rate: 1.000
# Request 179 	: Total cost: 90.680 	 Total delay: 231.314 	 Acceptance rate: 1.000
# Request 180 	: Total cost: 79.814 	 Total delay: 285.316 	 Acceptance rate: 1.000
# Request 181 	: Total cost: 108.638 	 Total delay: 372.009 	 Acceptance rate: 1.000
# Request 182 	: Total cost: 96.505 	 Total delay: 277.553 	 Acceptance rate: 1.000
# Request 183 	: Total cost: 153.718 	 Total delay: 308.297 	 Acceptance rate: 1.000
# Request 184 	: Total cost: 82.293 	 Total delay: 237.240 	 Acceptance rate: 1.000
# Request 185 	: Total cost: 116.589 	 Total delay: 209.949 	 Acceptance rate: 1.000
# Request 186 	: Total cost: 160.179 	 Total delay: 214.458 	 Acceptance rate: 1.000
# Request 187 	: Total cost: 139.150 	 Total delay: 520.844 	 Acceptance rate: 1.000
# Request 188 	: Total cost: 78.897 	 Total delay: 92.244 	 Acceptance rate: 1.000
# Request 189 	: Total cost: 57.494 	 Total delay: 136.967 	 Acceptance rate: 1.000
# Request 190 	: Total cost: 90.716 	 Total delay: 231.156 	 Acceptance rate: 1.000
# Request 191 	: Total cost: 135.907 	 Total delay: 444.620 	 Acceptance rate: 1.000
# Request 192 	: Total cost: 143.201 	 Total delay: 458.321 	 Acceptance rate: 1.000
# Request 193 	: Total cost: 91.929 	 Total delay: 164.980 	 Acceptance rate: 1.000
# Request 194 	: Total cost: 92.473 	 Total delay: 266.397 	 Acceptance rate: 1.000
# Request 195 	: Total cost: 105.215 	 Total delay: 176.636 	 Acceptance rate: 1.000
# Request 196 	: Total cost: 55.420 	 Total delay: 67.851 	 Acceptance rate: 1.000
# Request 197 	: Total cost: 147.058 	 Total delay: 194.229 	 Acceptance rate: 1.000
# Request 198 	: Total cost: 95.005 	 Total delay: 165.400 	 Acceptance rate: 1.000
# Request 199 	: Total cost: 95.598 	 Total delay: 96.566 	 Acceptance rate: 1.000
# Request 200 	: Total cost: 122.605 	 Total delay: 230.400 	 Acceptance rate: 1.000
# Request 201 	: Total cost: 114.548 	 Total delay: 279.080 	 Acceptance rate: 1.000
# Request 202 	: Total cost: 92.501 	 Total delay: 229.661 	 Acceptance rate: 1.000
# Request 203 	: Total cost: 142.968 	 Total delay: 338.626 	 Acceptance rate: 1.000
# Request 204 	: Total cost: 122.278 	 Total delay: 184.773 	 Acceptance rate: 1.000
# Request 205 	: Total cost: 128.230 	 Total delay: 240.917 	 Acceptance rate: 1.000
# Request 206 	: Total cost: 165.542 	 Total delay: 272.190 	 Acceptance rate: 1.000
# Request 207 	: Total cost: 62.461 	 Total delay: 105.180 	 Acceptance rate: 1.000
# Request 208 	: Total cost: 119.753 	 Total delay: 155.943 	 Acceptance rate: 1.000
# Request 209 	: Total cost: 99.680 	 Total delay: 291.788 	 Acceptance rate: 1.000
# Request 210 	: Total cost: 103.929 	 Total delay: 241.400 	 Acceptance rate: 1.000
# Request 211 	: Total cost: 101.246 	 Total delay: 171.085 	 Acceptance rate: 1.000
# Request 212 	: Total cost: 95.504 	 Total delay: 117.412 	 Acceptance rate: 1.000
# Request 213 	: Total cost: 110.325 	 Total delay: 239.975 	 Acceptance rate: 1.000
# Request 214 	: Total cost: 131.139 	 Total delay: 274.567 	 Acceptance rate: 1.000
# Request 215 	: Total cost: 95.165 	 Total delay: 157.335 	 Acceptance rate: 1.000
# Request 216 	: Total cost: 111.475 	 Total delay: 273.207 	 Acceptance rate: 1.000
# Request 217 	: Total cost: 114.790 	 Total delay: 294.530 	 Acceptance rate: 1.000
# Request 218 	: Total cost: 99.755 	 Total delay: 275.174 	 Acceptance rate: 1.000
# Request 219 	: Total cost: 126.065 	 Total delay: 320.498 	 Acceptance rate: 1.000
# Request 220 	: Total cost: 114.443 	 Total delay: 337.959 	 Acceptance rate: 1.000
# Request 221 	: Total cost: 130.597 	 Total delay: 255.002 	 Acceptance rate: 1.000
# Request 222 	: Total cost: 96.587 	 Total delay: 220.281 	 Acceptance rate: 1.000
# Request 223 	: Total cost: 186.849 	 Total delay: 366.840 	 Acceptance rate: 1.000
# Request 224 	: Total cost: 104.741 	 Total delay: 326.622 	 Acceptance rate: 1.000
# Request 225 	: Total cost: 97.453 	 Total delay: 145.904 	 Acceptance rate: 1.000
# Request 226 	: Total cost: 130.636 	 Total delay: 242.920 	 Acceptance rate: 1.000
# Request 227 	: Total cost: 94.774 	 Total delay: 183.948 	 Acceptance rate: 1.000
# Request 228 	: Total cost: 146.351 	 Total delay: 420.038 	 Acceptance rate: 1.000
# Request 229 	: Total cost: 91.284 	 Total delay: 132.553 	 Acceptance rate: 1.000
# Request 230 	: Total cost: 89.609 	 Total delay: 213.521 	 Acceptance rate: 1.000
# Request 231 	: Total cost: 125.720 	 Total delay: 220.533 	 Acceptance rate: 1.000
# Request 232 	: Total cost: 104.475 	 Total delay: 244.906 	 Acceptance rate: 1.000
# Request 233 	: Total cost: 108.664 	 Total delay: 281.590 	 Acceptance rate: 1.000
# Request 234 	: Total cost: 109.628 	 Total delay: 220.306 	 Acceptance rate: 1.000
# Request 235 	: Total cost: 100.520 	 Total delay: 274.721 	 Acceptance rate: 1.000
# Request 236 	: Total cost: 162.560 	 Total delay: 291.503 	 Acceptance rate: 1.000
# Request 237 	: Total cost: 84.201 	 Total delay: 135.867 	 Acceptance rate: 1.000
# Request 238 	: Total cost: 92.730 	 Total delay: 187.594 	 Acceptance rate: 1.000
# Request 239 	: Total cost: 100.034 	 Total delay: 132.554 	 Acceptance rate: 1.000
# Request 240 	: Total cost: 99.834 	 Total delay: 353.523 	 Acceptance rate: 1.000
# Request 241 	: Total cost: 157.514 	 Total delay: 259.418 	 Acceptance rate: 1.000
# Request 242 	: Total cost: 133.374 	 Total delay: 281.691 	 Acceptance rate: 1.000
# Request 243 	: Total cost: 121.009 	 Total delay: 122.406 	 Acceptance rate: 1.000
# Request 244 	: Total cost: 98.995 	 Total delay: 130.212 	 Acceptance rate: 1.000
# Request 245 	: Total cost: 150.629 	 Total delay: 398.368 	 Acceptance rate: 1.000
# Request 246 	: Total cost: 91.067 	 Total delay: 154.437 	 Acceptance rate: 1.000
# Request 247 	: Total cost: 87.869 	 Total delay: 159.231 	 Acceptance rate: 1.000
# Request 248 	: Total cost: 110.978 	 Total delay: 190.513 	 Acceptance rate: 1.000
# Request 249 	: Total cost: 73.360 	 Total delay: 153.075 	 Acceptance rate: 1.000
# Request 250 	: Total cost: 95.332 	 Total delay: 217.678 	 Acceptance rate: 1.000
# Request 251 	: Total cost: 118.677 	 Total delay: 306.977 	 Acceptance rate: 1.000
# Request 252 	: Total cost: 109.082 	 Total delay: 280.905 	 Acceptance rate: 1.000
# Request 253 	: Total cost: 82.463 	 Total delay: 188.456 	 Acceptance rate: 1.000
# Request 254 	: Total cost: 136.175 	 Total delay: 262.375 	 Acceptance rate: 1.000
# Request 255 	: Total cost: 95.966 	 Total delay: 145.932 	 Acceptance rate: 1.000
# Request 256 	: Total cost: 114.501 	 Total delay: 322.653 	 Acceptance rate: 1.000
# Request 257 	: Total cost: 130.197 	 Total delay: 268.163 	 Acceptance rate: 1.000
# Request 258 	: Total cost: 74.442 	 Total delay: 144.622 	 Acceptance rate: 1.000
# Request 259 	: Total cost: 114.370 	 Total delay: 325.817 	 Acceptance rate: 1.000
# Request 260 	: Total cost: 83.469 	 Total delay: 148.642 	 Acceptance rate: 1.000
# Request 261 	: Total cost: 164.542 	 Total delay: 454.364 	 Acceptance rate: 1.000
# Request 262 	: Total cost: 163.904 	 Total delay: 435.040 	 Acceptance rate: 1.000
# Request 263 	: Total cost: 57.018 	 Total delay: 97.677 	 Acceptance rate: 1.000
# Request 264 	: Total cost: 137.584 	 Total delay: 292.518 	 Acceptance rate: 1.000
# Request 265 	: Total cost: 114.397 	 Total delay: 104.232 	 Acceptance rate: 1.000
# Request 266 	: Total cost: 133.548 	 Total delay: 222.760 	 Acceptance rate: 1.000
# Request 267 	: Total cost: 96.718 	 Total delay: 128.298 	 Acceptance rate: 1.000
# Request 268 	: Total cost: 171.738 	 Total delay: 257.820 	 Acceptance rate: 1.000
# Request 269 	: Total cost: 62.645 	 Total delay: 153.407 	 Acceptance rate: 1.000
# Request 270 	: Total cost: 92.685 	 Total delay: 147.435 	 Acceptance rate: 1.000
# Request 271 	: Total cost: 100.237 	 Total delay: 199.178 	 Acceptance rate: 1.000
# Request 272 	: Total cost: 110.798 	 Total delay: 273.298 	 Acceptance rate: 1.000
# Request 273 	: Total cost: 52.118 	 Total delay: 339.841 	 Acceptance rate: 1.000
# Request 274 	: Total cost: 140.911 	 Total delay: 343.270 	 Acceptance rate: 1.000
# Request 275 	: Total cost: 96.901 	 Total delay: 224.743 	 Acceptance rate: 1.000
# Request 276 	: Total cost: 99.410 	 Total delay: 151.662 	 Acceptance rate: 1.000
# Request 277 	: Total cost: 127.963 	 Total delay: 251.989 	 Acceptance rate: 1.000
# Request 278 	: Total cost: 67.273 	 Total delay: 143.759 	 Acceptance rate: 1.000
# Request 279 	: Total cost: 60.688 	 Total delay: 132.002 	 Acceptance rate: 1.000
# Request 280 	: Total cost: 90.087 	 Total delay: 178.380 	 Acceptance rate: 1.000
# Request 281 	: Total cost: 127.221 	 Total delay: 222.950 	 Acceptance rate: 1.000
# Request 282 	: Total cost: 119.950 	 Total delay: 367.660 	 Acceptance rate: 1.000
# Request 283 	: Total cost: 60.475 	 Total delay: 235.038 	 Acceptance rate: 1.000
# Request 284 	: Total cost: 81.632 	 Total delay: 130.968 	 Acceptance rate: 1.000
# Request 285 	: Total cost: 80.823 	 Total delay: 206.345 	 Acceptance rate: 1.000
# Request 286 	: Total cost: 119.826 	 Total delay: 411.037 	 Acceptance rate: 1.000
# Request 287 	: Total cost: 140.960 	 Total delay: 210.822 	 Acceptance rate: 1.000
# Request 288 	: Total cost: 99.978 	 Total delay: 355.211 	 Acceptance rate: 1.000
# Request 289 	: Total cost: 69.377 	 Total delay: 257.996 	 Acceptance rate: 1.000
# Request 290 	: Total cost: 87.929 	 Total delay: 199.669 	 Acceptance rate: 1.000
# Request 291 	: Total cost: 89.689 	 Total delay: 95.913 	 Acceptance rate: 1.000
# Request 292 	: Total cost: 142.325 	 Total delay: 174.199 	 Acceptance rate: 1.000
# Request 293 	: Total cost: 125.134 	 Total delay: 190.292 	 Acceptance rate: 1.000
# Request 294 	: Total cost: 140.923 	 Total delay: 333.756 	 Acceptance rate: 1.000
# Request 295 	: Total cost: 153.405 	 Total delay: 324.393 	 Acceptance rate: 1.000
# Request 296 	: Total cost: 69.138 	 Total delay: 77.562 	 Acceptance rate: 1.000
# Request 297 	: Total cost: 90.632 	 Total delay: 290.455 	 Acceptance rate: 1.000
# Request 298 	: Total cost: 65.014 	 Total delay: 203.224 	 Acceptance rate: 1.000
# Request 299 	: Total cost: 77.063 	 Total delay: 166.572 	 Acceptance rate: 1.000
# Request 300 	: Total cost: 95.025 	 Total delay: 212.729 	 Acceptance rate: 1.000
# Request 301 	: Total cost: 134.123 	 Total delay: 390.701 	 Acceptance rate: 1.000
# Request 302 	: Total cost: 75.479 	 Total delay: 188.654 	 Acceptance rate: 1.000
# Request 303 	: Total cost: 122.558 	 Total delay: 285.467 	 Acceptance rate: 1.000
# Request 304 	: Total cost: 114.617 	 Total delay: 250.205 	 Acceptance rate: 1.000
# Request 305 	: Total cost: 102.175 	 Total delay: 154.907 	 Acceptance rate: 1.000
# Request 306 	: Total cost: 114.463 	 Total delay: 161.392 	 Acceptance rate: 1.000
# Request 307 	: Total cost: 93.354 	 Total delay: 221.223 	 Acceptance rate: 1.000
# Request 308 	: Total cost: 71.006 	 Total delay: 134.988 	 Acceptance rate: 1.000
# Request 309 	: Total cost: 73.560 	 Total delay: 71.545 	 Acceptance rate: 1.000
# Request 310 	: Total cost: 110.877 	 Total delay: 176.362 	 Acceptance rate: 1.000
# Request 311 	: Total cost: 148.197 	 Total delay: 410.334 	 Acceptance rate: 1.000
# Request 312 	: Total cost: 104.161 	 Total delay: 213.587 	 Acceptance rate: 1.000
# Request 313 	: Total cost: 122.397 	 Total delay: 266.022 	 Acceptance rate: 1.000
# Request 314 	: Total cost: 79.763 	 Total delay: 200.469 	 Acceptance rate: 1.000
# Request 315 	: Total cost: 143.838 	 Total delay: 469.746 	 Acceptance rate: 1.000
# Request 316 	: Total cost: 119.542 	 Total delay: 307.684 	 Acceptance rate: 1.000
# Request 317 	: Total cost: 107.264 	 Total delay: 264.579 	 Acceptance rate: 1.000
# Request 318 	: Total cost: 123.163 	 Total delay: 298.041 	 Acceptance rate: 1.000
# Request 319 	: Total cost: 140.015 	 Total delay: 284.499 	 Acceptance rate: 1.000
# Request 320 	: Total cost: 147.172 	 Total delay: 358.451 	 Acceptance rate: 1.000
# Request 321 	: Total cost: 77.225 	 Total delay: 145.968 	 Acceptance rate: 1.000
# Request 322 	: Total cost: 94.396 	 Total delay: 148.320 	 Acceptance rate: 1.000
# Request 323 	: Total cost: 135.240 	 Total delay: 311.112 	 Acceptance rate: 1.000
# Request 324 	: Total cost: 90.206 	 Total delay: 126.593 	 Acceptance rate: 1.000
# Request 325 	: Total cost: 157.778 	 Total delay: 260.402 	 Acceptance rate: 1.000
# Request 326 	: Total cost: 79.915 	 Total delay: 153.941 	 Acceptance rate: 1.000
# Request 327 	: Total cost: 101.893 	 Total delay: 222.364 	 Acceptance rate: 1.000
# Request 328 	: Total cost: 87.062 	 Total delay: 255.458 	 Acceptance rate: 1.000
# Request 329 	: Total cost: 114.837 	 Total delay: 150.077 	 Acceptance rate: 1.000
# Request 330 	: Total cost: 121.281 	 Total delay: 197.429 	 Acceptance rate: 1.000
# Request 331 	: Total cost: 110.026 	 Total delay: 194.111 	 Acceptance rate: 1.000
# Request 332 	: Total cost: 110.460 	 Total delay: 233.620 	 Acceptance rate: 1.000
# Request 333 	: Total cost: 73.992 	 Total delay: 173.840 	 Acceptance rate: 1.000
# Request 334 	: Total cost: 135.725 	 Total delay: 265.935 	 Acceptance rate: 1.000
# Request 335 	: Total cost: 121.413 	 Total delay: 200.543 	 Acceptance rate: 1.000
# Request 336 	: Total cost: 86.234 	 Total delay: 177.480 	 Acceptance rate: 1.000
# Request 337 	: Total cost: 141.087 	 Total delay: 367.995 	 Acceptance rate: 1.000
# Request 338 	: Total cost: 162.451 	 Total delay: 445.607 	 Acceptance rate: 1.000
# Request 339 	: Total cost: 100.524 	 Total delay: 169.048 	 Acceptance rate: 1.000
# Request 340 	: Total cost: 112.596 	 Total delay: 304.401 	 Acceptance rate: 1.000
# Request 341 	: Total cost: 94.105 	 Total delay: 259.062 	 Acceptance rate: 1.000
# Request 342 	: Total cost: 89.331 	 Total delay: 101.364 	 Acceptance rate: 1.000
# Request 343 	: Total cost: 115.459 	 Total delay: 412.661 	 Acceptance rate: 1.000
# Request 344 	: Total cost: 143.487 	 Total delay: 209.994 	 Acceptance rate: 1.000
# Request 345 	: Total cost: 207.564 	 Total delay: 395.030 	 Acceptance rate: 1.000
# Request 346 	: Total cost: 109.180 	 Total delay: 204.004 	 Acceptance rate: 1.000
# Request 347 	: Total cost: 102.190 	 Total delay: 226.115 	 Acceptance rate: 1.000
# Request 348 	: Total cost: 96.562 	 Total delay: 295.289 	 Acceptance rate: 1.000
# Request 349 	: Total cost: 121.796 	 Total delay: 369.004 	 Acceptance rate: 1.000
# Request 350 	: Total cost: 111.531 	 Total delay: 190.938 	 Acceptance rate: 1.000
# Request 351 	: Total cost: 96.107 	 Total delay: 287.371 	 Acceptance rate: 1.000
# Request 352 	: Total cost: 136.391 	 Total delay: 356.403 	 Acceptance rate: 1.000
# Request 353 	: Total cost: 159.849 	 Total delay: 275.858 	 Acceptance rate: 1.000
# Request 354 	: Total cost: 104.181 	 Total delay: 227.237 	 Acceptance rate: 1.000
# Request 355 	: Total cost: 89.976 	 Total delay: 300.875 	 Acceptance rate: 1.000
# Request 356 	: Total cost: 113.994 	 Total delay: 308.309 	 Acceptance rate: 1.000
# Request 357 	: Total cost: 112.348 	 Total delay: 139.911 	 Acceptance rate: 1.000
# Request 358 	: Total cost: 84.890 	 Total delay: 181.828 	 Acceptance rate: 1.000
# Request 359 	: Total cost: 127.747 	 Total delay: 248.259 	 Acceptance rate: 1.000
# Request 360 	: Total cost: 138.829 	 Total delay: 363.615 	 Acceptance rate: 1.000
# Request 361 	: Total cost: 97.817 	 Total delay: 166.293 	 Acceptance rate: 1.000
# Request 362 	: Total cost: 94.795 	 Total delay: 117.432 	 Acceptance rate: 1.000
# Request 363 	: Total cost: 119.867 	 Total delay: 277.585 	 Acceptance rate: 1.000
# Request 364 	: Total cost: 77.129 	 Total delay: 187.166 	 Acceptance rate: 1.000
# Request 365 	: Total cost: 122.405 	 Total delay: 333.004 	 Acceptance rate: 1.000
# Request 366 	: Total cost: 141.013 	 Total delay: 339.529 	 Acceptance rate: 1.000
# Request 367 	: Total cost: 93.552 	 Total delay: 213.271 	 Acceptance rate: 1.000
# Request 368 	: Total cost: 131.126 	 Total delay: 253.153 	 Acceptance rate: 1.000
# Request 369 	: Total cost: 79.941 	 Total delay: 277.809 	 Acceptance rate: 1.000
# Request 370 	: Total cost: 73.902 	 Total delay: 218.481 	 Acceptance rate: 1.000
# Request 371 	: Total cost: 123.000 	 Total delay: 147.763 	 Acceptance rate: 1.000
# Request 372 	: Total cost: 60.162 	 Total delay: 108.631 	 Acceptance rate: 1.000
# Request 373 	: Total cost: 118.413 	 Total delay: 414.445 	 Acceptance rate: 1.000
# Request 374 	: Total cost: 162.544 	 Total delay: 376.353 	 Acceptance rate: 1.000
# Request 375 	: Total cost: 79.639 	 Total delay: 140.105 	 Acceptance rate: 1.000
# Request 376 	: Total cost: 95.300 	 Total delay: 236.672 	 Acceptance rate: 1.000
# Request 377 	: Total cost: 75.625 	 Total delay: 110.872 	 Acceptance rate: 1.000
# Request 378 	: Total cost: 105.236 	 Total delay: 307.712 	 Acceptance rate: 1.000
# Request 379 	: Total cost: 102.302 	 Total delay: 202.001 	 Acceptance rate: 1.000
# Request 380 	: Total cost: 106.727 	 Total delay: 177.282 	 Acceptance rate: 1.000
# Request 381 	: Total cost: 80.607 	 Total delay: 148.036 	 Acceptance rate: 1.000
# Request 382 	: Total cost: 53.527 	 Total delay: 110.000 	 Acceptance rate: 1.000
# Request 383 	: Total cost: 114.248 	 Total delay: 377.641 	 Acceptance rate: 1.000
# Request 384 	: Total cost: 44.463 	 Total delay: 319.203 	 Acceptance rate: 1.000
# Request 385 	: Total cost: 91.447 	 Total delay: 163.750 	 Acceptance rate: 1.000
# Request 386 	: Total cost: 131.569 	 Total delay: 338.124 	 Acceptance rate: 1.000
# Request 387 	: Total cost: 88.286 	 Total delay: 203.438 	 Acceptance rate: 1.000
# Request 388 	: Total cost: 141.020 	 Total delay: 249.975 	 Acceptance rate: 1.000
# Request 389 	: Total cost: 107.007 	 Total delay: 272.456 	 Acceptance rate: 1.000
# Request 390 	: Total cost: 123.852 	 Total delay: 329.687 	 Acceptance rate: 1.000
# Request 391 	: Total cost: 117.805 	 Total delay: 338.686 	 Acceptance rate: 1.000
# Request 392 	: Total cost: 64.094 	 Total delay: 62.849 	 Acceptance rate: 1.000
# Request 393 	: Total cost: 104.500 	 Total delay: 201.408 	 Acceptance rate: 1.000
# Request 394 	: Total cost: 116.494 	 Total delay: 236.206 	 Acceptance rate: 1.000
# Request 395 	: Total cost: 136.718 	 Total delay: 377.555 	 Acceptance rate: 1.000
# Request 396 	: Total cost: 162.192 	 Total delay: 326.573 	 Acceptance rate: 1.000
# Request 397 	: Total cost: 107.806 	 Total delay: 243.799 	 Acceptance rate: 1.000
# Request 398 	: Total cost: 186.355 	 Total delay: 428.846 	 Acceptance rate: 1.000
# Request 399 	: Total cost: 99.777 	 Total delay: 139.048 	 Acceptance rate: 1.000
# Request 400 	: Total cost: 100.197 	 Total delay: 180.282 	 Acceptance rate: 1.000
# Request 401 	: Total cost: 157.232 	 Total delay: 356.907 	 Acceptance rate: 1.000
# Request 402 	: Total cost: 106.880 	 Total delay: 136.575 	 Acceptance rate: 1.000
# Request 403 	: Total cost: 111.250 	 Total delay: 198.279 	 Acceptance rate: 1.000
# Request 404 	: Total cost: 106.345 	 Total delay: 225.959 	 Acceptance rate: 1.000
# Request 405 	: Total cost: 95.200 	 Total delay: 221.577 	 Acceptance rate: 1.000
# Request 406 	: Total cost: 84.558 	 Total delay: 285.924 	 Acceptance rate: 1.000
# Request 407 	: Total cost: 104.609 	 Total delay: 273.455 	 Acceptance rate: 1.000
# Request 408 	: Total cost: 136.447 	 Total delay: 408.763 	 Acceptance rate: 1.000
# Request 409 	: Total cost: 85.151 	 Total delay: 155.703 	 Acceptance rate: 1.000
# Request 410 	: Total cost: 110.223 	 Total delay: 250.514 	 Acceptance rate: 1.000
# Request 411 	: Total cost: 92.332 	 Total delay: 140.961 	 Acceptance rate: 1.000
# Request 412 	: Total cost: 79.542 	 Total delay: 283.691 	 Acceptance rate: 1.000
# Request 413 	: Total cost: 105.160 	 Total delay: 185.904 	 Acceptance rate: 1.000
# Request 414 	: Total cost: 125.528 	 Total delay: 248.037 	 Acceptance rate: 1.000
# Request 415 	: Total cost: 53.403 	 Total delay: 125.070 	 Acceptance rate: 1.000
# Request 416 	: Total cost: 95.926 	 Total delay: 102.044 	 Acceptance rate: 1.000
# Request 417 	: Total cost: 79.667 	 Total delay: 242.545 	 Acceptance rate: 1.000
# Request 418 	: Total cost: 134.861 	 Total delay: 277.854 	 Acceptance rate: 1.000
# Request 419 	: Total cost: 104.494 	 Total delay: 179.383 	 Acceptance rate: 1.000
# Request 420 	: Total cost: 88.637 	 Total delay: 248.298 	 Acceptance rate: 1.000
# Request 421 	: Total cost: 88.250 	 Total delay: 89.857 	 Acceptance rate: 1.000
# Request 422 	: Total cost: 96.256 	 Total delay: 155.871 	 Acceptance rate: 1.000
# Request 423 	: Total cost: 87.662 	 Total delay: 247.063 	 Acceptance rate: 1.000
# Request 424 	: Total cost: 73.762 	 Total delay: 124.222 	 Acceptance rate: 1.000
# Request 425 	: Total cost: 208.298 	 Total delay: 442.835 	 Acceptance rate: 1.000
# Request 426 	: Total cost: 96.626 	 Total delay: 270.049 	 Acceptance rate: 1.000
# Request 427 	: Total cost: 75.320 	 Total delay: 123.284 	 Acceptance rate: 1.000
# Request 428 	: Total cost: 99.397 	 Total delay: 213.673 	 Acceptance rate: 1.000
# Request 429 	: Total cost: 140.354 	 Total delay: 400.251 	 Acceptance rate: 1.000
# Request 430 	: Total cost: 118.592 	 Total delay: 253.488 	 Acceptance rate: 1.000
# Request 431 	: Total cost: 131.013 	 Total delay: 374.442 	 Acceptance rate: 1.000
# Request 432 	: Total cost: 132.858 	 Total delay: 193.073 	 Acceptance rate: 1.000
# Request 433 	: Total cost: 150.203 	 Total delay: 301.676 	 Acceptance rate: 1.000
# Request 434 	: Total cost: 104.449 	 Total delay: 121.867 	 Acceptance rate: 1.000
# Request 435 	: Total cost: 138.211 	 Total delay: 204.641 	 Acceptance rate: 1.000
# Request 436 	: Total cost: 123.318 	 Total delay: 249.868 	 Acceptance rate: 1.000
# Request 437 	: Total cost: 118.343 	 Total delay: 365.364 	 Acceptance rate: 1.000
# Request 438 	: Total cost: 86.922 	 Total delay: 139.932 	 Acceptance rate: 1.000
# Request 439 	: Total cost: 76.920 	 Total delay: 155.646 	 Acceptance rate: 1.000
# Request 440 	: Total cost: 153.761 	 Total delay: 432.224 	 Acceptance rate: 1.000
# Request 441 	: Total cost: 87.511 	 Total delay: 208.351 	 Acceptance rate: 1.000
# Request 442 	: Total cost: 60.278 	 Total delay: 81.806 	 Acceptance rate: 1.000
# Request 443 	: Total cost: 131.109 	 Total delay: 171.146 	 Acceptance rate: 1.000
# Request 444 	: Total cost: 97.616 	 Total delay: 172.211 	 Acceptance rate: 1.000
# Request 445 	: Total cost: 195.421 	 Total delay: 356.660 	 Acceptance rate: 1.000
# Request 446 	: Total cost: 139.919 	 Total delay: 289.258 	 Acceptance rate: 1.000
# Request 447 	: Total cost: 118.251 	 Total delay: 403.099 	 Acceptance rate: 1.000
# Request 448 	: Total cost: 138.719 	 Total delay: 380.259 	 Acceptance rate: 1.000
# Request 449 	: Total cost: 103.693 	 Total delay: 226.275 	 Acceptance rate: 1.000
# Request 450 	: Total cost: 72.843 	 Total delay: 104.374 	 Acceptance rate: 1.000
# Request 451 	: Total cost: 119.833 	 Total delay: 302.761 	 Acceptance rate: 1.000
# Request 452 	: Total cost: 99.918 	 Total delay: 123.410 	 Acceptance rate: 1.000
# Request 453 	: Total cost: 83.912 	 Total delay: 180.786 	 Acceptance rate: 1.000
# Request 454 	: Total cost: 90.238 	 Total delay: 134.712 	 Acceptance rate: 1.000
# Request 455 	: Total cost: 75.160 	 Total delay: 99.325 	 Acceptance rate: 1.000
# Request 456 	: Total cost: 82.447 	 Total delay: 157.756 	 Acceptance rate: 1.000
# Request 457 	: Total cost: 111.223 	 Total delay: 140.356 	 Acceptance rate: 1.000
# Request 458 	: Total cost: 89.015 	 Total delay: 354.886 	 Acceptance rate: 1.000
# Request 459 	: Total cost: 111.622 	 Total delay: 171.106 	 Acceptance rate: 1.000
# Request 460 	: Total cost: 103.780 	 Total delay: 199.247 	 Acceptance rate: 1.000
# Request 461 	: Total cost: 148.513 	 Total delay: 338.626 	 Acceptance rate: 1.000
# Request 462 	: Total cost: 102.357 	 Total delay: 266.093 	 Acceptance rate: 1.000
# Request 463 	: Total cost: 88.295 	 Total delay: 175.182 	 Acceptance rate: 1.000
# Request 464 	: Total cost: 93.113 	 Total delay: 100.518 	 Acceptance rate: 1.000
# Request 465 	: Total cost: 178.746 	 Total delay: 352.340 	 Acceptance rate: 1.000
# Request 466 	: Total cost: 100.032 	 Total delay: 138.337 	 Acceptance rate: 1.000
# Request 467 	: Total cost: 97.729 	 Total delay: 291.268 	 Acceptance rate: 1.000
# Request 468 	: Total cost: 104.904 	 Total delay: 282.310 	 Acceptance rate: 1.000
# Request 469 	: Total cost: 136.722 	 Total delay: 229.468 	 Acceptance rate: 1.000
# Request 470 	: Total cost: 103.610 	 Total delay: 288.227 	 Acceptance rate: 1.000
# Request 471 	: Total cost: 122.406 	 Total delay: 303.776 	 Acceptance rate: 1.000
# Request 472 	: Total cost: 172.648 	 Total delay: 318.135 	 Acceptance rate: 1.000
# Request 473 	: Total cost: 87.496 	 Total delay: 348.325 	 Acceptance rate: 1.000
# Request 474 	: Total cost: 141.869 	 Total delay: 300.304 	 Acceptance rate: 1.000
# Request 475 	: Total cost: 100.739 	 Total delay: 174.046 	 Acceptance rate: 1.000
# Request 476 	: Total cost: 117.374 	 Total delay: 202.571 	 Acceptance rate: 1.000
# Request 477 	: Total cost: 197.356 	 Total delay: 459.050 	 Acceptance rate: 1.000
# Request 478 	: Total cost: 75.884 	 Total delay: 141.820 	 Acceptance rate: 1.000
# Request 479 	: Total cost: 72.965 	 Total delay: 124.577 	 Acceptance rate: 1.000
# Request 480 	: Total cost: 75.996 	 Total delay: 151.876 	 Acceptance rate: 1.000
# Request 481 	: Total cost: 112.398 	 Total delay: 176.104 	 Acceptance rate: 1.000
# Request 482 	: Total cost: 91.471 	 Total delay: 199.352 	 Acceptance rate: 1.000
# Request 483 	: Total cost: 95.136 	 Total delay: 168.059 	 Acceptance rate: 1.000
# Request 484 	: Total cost: 135.527 	 Total delay: 271.803 	 Acceptance rate: 1.000
# Request 485 	: Total cost: 106.109 	 Total delay: 140.200 	 Acceptance rate: 1.000
# Request 486 	: Total cost: 61.705 	 Total delay: 117.425 	 Acceptance rate: 1.000
# Request 487 	: Total cost: 73.150 	 Total delay: 225.311 	 Acceptance rate: 1.000
# Request 488 	: Total cost: 102.251 	 Total delay: 196.715 	 Acceptance rate: 1.000
# Request 489 	: Total cost: 159.591 	 Total delay: 218.983 	 Acceptance rate: 1.000
# Request 490 	: Total cost: 63.222 	 Total delay: 102.350 	 Acceptance rate: 1.000
# Request 491 	: Total cost: 123.618 	 Total delay: 154.364 	 Acceptance rate: 1.000
# Request 492 	: Total cost: 147.560 	 Total delay: 262.019 	 Acceptance rate: 1.000
# Request 493 	: Total cost: 125.994 	 Total delay: 354.080 	 Acceptance rate: 1.000
# Request 494 	: Total cost: 122.892 	 Total delay: 291.020 	 Acceptance rate: 1.000
# Request 495 	: Total cost: 151.530 	 Total delay: 399.006 	 Acceptance rate: 1.000
# Request 496 	: Total cost: 87.147 	 Total delay: 224.536 	 Acceptance rate: 1.000
# Request 497 	: Total cost: 100.292 	 Total delay: 211.116 	 Acceptance rate: 1.000
# Request 498 	: Total cost: 126.046 	 Total delay: 215.705 	 Acceptance rate: 1.000
# Request 499 	: Total cost: 85.847 	 Total delay: 208.122 	 Acceptance rate: 1.000
# Request 500 	: Total cost: 54.368 	 Total delay: 75.121 	 Acceptance rate: 1.000
# Request 501 	: Total cost: 63.851 	 Total delay: 133.761 	 Acceptance rate: 1.000
# Request 502 	: Total cost: 144.674 	 Total delay: 196.692 	 Acceptance rate: 1.000
# Request 503 	: Total cost: 110.326 	 Total delay: 246.517 	 Acceptance rate: 1.000
# Request 504 	: Total cost: 89.137 	 Total delay: 187.658 	 Acceptance rate: 1.000
# Request 505 	: Total cost: 91.404 	 Total delay: 127.441 	 Acceptance rate: 1.000
# Request 506 	: Total cost: 173.680 	 Total delay: 364.143 	 Acceptance rate: 1.000
# Request 507 	: Total cost: 105.943 	 Total delay: 279.629 	 Acceptance rate: 1.000
# Request 508 	: Total cost: 123.181 	 Total delay: 272.957 	 Acceptance rate: 1.000
# Request 509 	: Total cost: 69.729 	 Total delay: 112.488 	 Acceptance rate: 1.000
# Request 510 	: Total cost: 107.366 	 Total delay: 156.726 	 Acceptance rate: 1.000
# Request 511 	: Total cost: 127.076 	 Total delay: 267.912 	 Acceptance rate: 1.000
# Request 512 	: Total cost: 59.678 	 Total delay: 126.895 	 Acceptance rate: 1.000
# Request 513 	: Total cost: 97.813 	 Total delay: 266.340 	 Acceptance rate: 1.000
# Request 514 	: Total cost: 76.834 	 Total delay: 143.161 	 Acceptance rate: 1.000
# Request 515 	: Total cost: 89.711 	 Total delay: 151.362 	 Acceptance rate: 1.000
# Request 516 	: Total cost: 64.758 	 Total delay: 151.993 	 Acceptance rate: 1.000
# Request 517 	: Total cost: 58.576 	 Total delay: 97.897 	 Acceptance rate: 1.000
# Request 518 	: Total cost: 134.100 	 Total delay: 251.970 	 Acceptance rate: 1.000
# Request 519 	: Total cost: 96.536 	 Total delay: 258.968 	 Acceptance rate: 1.000
# Request 520 	: Total cost: 82.003 	 Total delay: 238.102 	 Acceptance rate: 1.000
# Request 521 	: Total cost: 117.165 	 Total delay: 287.933 	 Acceptance rate: 1.000
# Request 522 	: Total cost: 109.164 	 Total delay: 203.824 	 Acceptance rate: 1.000
# Request 523 	: Total cost: 122.378 	 Total delay: 313.501 	 Acceptance rate: 1.000
# Request 524 	: Total cost: 82.463 	 Total delay: 196.318 	 Acceptance rate: 1.000
# Request 525 	: Total cost: 119.764 	 Total delay: 518.531 	 Acceptance rate: 1.000
# Request 526 	: Total cost: 168.738 	 Total delay: 487.406 	 Acceptance rate: 1.000
# Request 527 	: Total cost: 120.632 	 Total delay: 208.382 	 Acceptance rate: 1.000
# Request 528 	: Total cost: 127.520 	 Total delay: 321.518 	 Acceptance rate: 1.000
# Request 529 	: Total cost: 55.552 	 Total delay: 85.535 	 Acceptance rate: 1.000
# Request 530 	: Total cost: 118.378 	 Total delay: 386.682 	 Acceptance rate: 1.000
# Request 531 	: Total cost: 99.242 	 Total delay: 234.925 	 Acceptance rate: 1.000
# Request 532 	: Total cost: 122.304 	 Total delay: 326.014 	 Acceptance rate: 1.000
# Request 533 	: Total cost: 99.275 	 Total delay: 147.136 	 Acceptance rate: 1.000
# Request 534 	: Total cost: 96.042 	 Total delay: 221.341 	 Acceptance rate: 1.000
# Request 535 	: Total cost: 137.227 	 Total delay: 211.053 	 Acceptance rate: 1.000
# Request 536 	: Total cost: 84.568 	 Total delay: 110.178 	 Acceptance rate: 1.000
# Request 537 	: Total cost: 98.061 	 Total delay: 228.948 	 Acceptance rate: 1.000
# Request 538 	: Total cost: 82.644 	 Total delay: 168.280 	 Acceptance rate: 1.000
# Request 539 	: Total cost: 136.566 	 Total delay: 317.153 	 Acceptance rate: 1.000
# Request 540 	: Total cost: 89.353 	 Total delay: 141.214 	 Acceptance rate: 1.000
# Request 541 	: Total cost: 103.900 	 Total delay: 186.427 	 Acceptance rate: 1.000
# Request 542 	: Total cost: 72.461 	 Total delay: 129.448 	 Acceptance rate: 1.000
# Request 543 	: Total cost: 105.373 	 Total delay: 175.840 	 Acceptance rate: 1.000
# Request 544 	: Total cost: 100.880 	 Total delay: 140.102 	 Acceptance rate: 1.000
# Request 545 	: Total cost: 105.923 	 Total delay: 200.785 	 Acceptance rate: 1.000
# Request 546 	: Total cost: 124.195 	 Total delay: 240.482 	 Acceptance rate: 1.000
# Request 547 	: Total cost: 99.948 	 Total delay: 297.743 	 Acceptance rate: 1.000
# Request 548 	: Total cost: 153.227 	 Total delay: 245.403 	 Acceptance rate: 1.000
# Request 549 	: Total cost: 84.478 	 Total delay: 122.230 	 Acceptance rate: 1.000
# Request 550 	: Total cost: 118.438 	 Total delay: 314.433 	 Acceptance rate: 1.000
# Request 551 	: Total cost: 103.442 	 Total delay: 307.166 	 Acceptance rate: 1.000
# Request 552 	: Total cost: 99.002 	 Total delay: 215.678 	 Acceptance rate: 1.000
# Request 553 	: Total cost: 168.615 	 Total delay: 363.337 	 Acceptance rate: 1.000
# Request 554 	: Total cost: 141.003 	 Total delay: 369.003 	 Acceptance rate: 1.000
# Request 555 	: Total cost: 60.836 	 Total delay: 166.022 	 Acceptance rate: 1.000
# Request 556 	: Total cost: 71.522 	 Total delay: 150.739 	 Acceptance rate: 1.000
# Request 557 	: Total cost: 105.039 	 Total delay: 199.291 	 Acceptance rate: 1.000
# Request 558 	: Total cost: 97.877 	 Total delay: 200.792 	 Acceptance rate: 1.000
# Request 559 	: Total cost: 101.878 	 Total delay: 273.143 	 Acceptance rate: 1.000
# Request 560 	: Total cost: 77.063 	 Total delay: 106.675 	 Acceptance rate: 1.000
# Request 561 	: Total cost: 113.446 	 Total delay: 125.646 	 Acceptance rate: 1.000
# Request 562 	: Total cost: 83.733 	 Total delay: 273.319 	 Acceptance rate: 1.000
# Request 563 	: Total cost: 148.138 	 Total delay: 343.616 	 Acceptance rate: 1.000
# Request 564 	: Total cost: 101.914 	 Total delay: 184.587 	 Acceptance rate: 1.000
# Request 565 	: Total cost: 83.320 	 Total delay: 266.226 	 Acceptance rate: 1.000
# Request 566 	: Total cost: 106.294 	 Total delay: 216.154 	 Acceptance rate: 1.000
# Request 567 	: Total cost: 46.397 	 Total delay: 80.547 	 Acceptance rate: 1.000
# Request 568 	: Total cost: 89.438 	 Total delay: 233.737 	 Acceptance rate: 1.000
# Request 569 	: Total cost: 142.659 	 Total delay: 319.146 	 Acceptance rate: 1.000
# Request 570 	: Total cost: 145.662 	 Total delay: 265.172 	 Acceptance rate: 1.000
# Request 571 	: Total cost: 134.839 	 Total delay: 243.408 	 Acceptance rate: 1.000
# Request 572 	: Total cost: 176.606 	 Total delay: 336.469 	 Acceptance rate: 1.000
# Request 573 	: Total cost: 133.209 	 Total delay: 411.160 	 Acceptance rate: 1.000
# Request 574 	: Total cost: 119.450 	 Total delay: 247.822 	 Acceptance rate: 1.000
# Request 575 	: Total cost: 67.615 	 Total delay: 66.851 	 Acceptance rate: 1.000
# Request 576 	: Total cost: 82.363 	 Total delay: 213.447 	 Acceptance rate: 1.000
# Request 577 	: Total cost: 88.067 	 Total delay: 193.192 	 Acceptance rate: 1.000
# Request 578 	: Total cost: 88.170 	 Total delay: 167.367 	 Acceptance rate: 1.000
# Request 579 	: Total cost: 97.242 	 Total delay: 227.188 	 Acceptance rate: 1.000
# Request 580 	: Total cost: 140.252 	 Total delay: 230.490 	 Acceptance rate: 1.000
# Request 581 	: Total cost: 77.681 	 Total delay: 148.494 	 Acceptance rate: 1.000
# Request 582 	: Total cost: 65.731 	 Total delay: 68.342 	 Acceptance rate: 1.000
# Request 583 	: Total cost: 115.310 	 Total delay: 276.785 	 Acceptance rate: 1.000
# ...
# Request 2236 	: Total cost: 126.472 	 Total delay: 212.842 	 Acceptance rate: 1.000
# Request 2237 	: Total cost: 110.962 	 Total delay: 215.630 	 Acceptance rate: 1.000
# Request 2238 	: Total cost: 112.601 	 Total delay: 136.406 	 Acceptance rate: 1.000
# Request 2239 	: Total cost: 90.700 	 Total delay: 270.475 	 Acceptance rate: 1.000
# Request 2240 	: Total cost: 145.393 	 Total delay: 239.250 	 Acceptance rate: 1.000
# Request 2241 	: Total cost: 153.969 	 Total delay: 293.384 	 Acceptance rate: 1.000
# Request 2242 	: Total cost: 75.098 	 Total delay: 149.163 	 Acceptance rate: 1.000
# Request 2243 	: Total cost: 132.758 	 Total delay: 188.081 	 Acceptance rate: 1.000
# Request 2244 	: Total cost: 73.662 	 Total delay: 191.561 	 Acceptance rate: 1.000
# Request 2245 	: Total cost: 70.102 	 Total delay: 233.080 	 Acceptance rate: 1.000
# Request 2246 	: Total cost: 152.290 	 Total delay: 382.641 	 Acceptance rate: 1.000
# Request 2247 	: Total cost: 72.336 	 Total delay: 83.320 	 Acceptance rate: 1.000
# Request 2248 	: Total cost: 114.897 	 Total delay: 220.025 	 Acceptance rate: 1.000
# Request 2249 	: Total cost: 93.655 	 Total delay: 84.084 	 Acceptance rate: 1.000
# Request 2250 	: Total cost: 104.783 	 Total delay: 148.251 	 Acceptance rate: 1.000
# Request 2251 	: Total cost: 108.624 	 Total delay: 177.646 	 Acceptance rate: 1.000
# Request 2252 	: Total cost: 98.047 	 Total delay: 262.274 	 Acceptance rate: 1.000
# Request 2253 	: Total cost: 125.026 	 Total delay: 259.089 	 Acceptance rate: 1.000
# Request 2254 	: Total cost: 128.925 	 Total delay: 138.180 	 Acceptance rate: 1.000
# Request 2255 	: Total cost: 142.260 	 Total delay: 207.056 	 Acceptance rate: 1.000
# Request 2256 	: Total cost: 143.494 	 Total delay: 428.305 	 Acceptance rate: 1.000
# Request 2257 	: Total cost: 118.393 	 Total delay: 283.046 	 Acceptance rate: 1.000
# Request 2258 	: Total cost: 73.501 	 Total delay: 119.415 	 Acceptance rate: 1.000
# Request 2259 	: Total cost: 97.587 	 Total delay: 282.908 	 Acceptance rate: 1.000
# Request 2260 	: Total cost: 124.511 	 Total delay: 476.464 	 Acceptance rate: 1.000
# Request 2261 	: Total cost: 105.659 	 Total delay: 250.729 	 Acceptance rate: 1.000
# Request 2262 	: Total cost: 114.480 	 Total delay: 217.407 	 Acceptance rate: 1.000
# Request 2263 	: Total cost: 83.012 	 Total delay: 168.839 	 Acceptance rate: 1.000
# Request 2264 	: Total cost: 102.727 	 Total delay: 148.761 	 Acceptance rate: 1.000
# Request 2265 	: Total cost: 103.605 	 Total delay: 260.042 	 Acceptance rate: 1.000
# Request 2266 	: Total cost: 149.165 	 Total delay: 298.738 	 Acceptance rate: 1.000
# Request 2267 	: Total cost: 103.954 	 Total delay: 258.989 	 Acceptance rate: 1.000
# Request 2268 	: Total cost: 66.481 	 Total delay: 160.444 	 Acceptance rate: 1.000
# Request 2269 	: Total cost: 82.263 	 Total delay: 134.172 	 Acceptance rate: 1.000
# Request 2270 	: Total cost: 84.841 	 Total delay: 204.153 	 Acceptance rate: 1.000
# Request 2271 	: Total cost: 105.532 	 Total delay: 152.506 	 Acceptance rate: 1.000
# Request 2272 	: Total cost: 224.696 	 Total delay: 323.601 	 Acceptance rate: 1.000
# Request 2273 	: Total cost: 88.959 	 Total delay: 180.911 	 Acceptance rate: 1.000
# Request 2274 	: Total cost: 120.636 	 Total delay: 198.594 	 Acceptance rate: 1.000
# Request 2275 	: Total cost: 53.188 	 Total delay: 88.222 	 Acceptance rate: 1.000
# Request 2276 	: Total cost: 145.067 	 Total delay: 415.389 	 Acceptance rate: 1.000
# Request 2277 	: Total cost: 134.751 	 Total delay: 299.748 	 Acceptance rate: 1.000
# Request 2278 	: Total cost: 63.912 	 Total delay: 90.279 	 Acceptance rate: 1.000
# Request 2279 	: Total cost: 74.110 	 Total delay: 141.913 	 Acceptance rate: 1.000
# Request 2280 	: Total cost: 100.160 	 Total delay: 208.005 	 Acceptance rate: 1.000
# Request 2281 	: Total cost: 112.624 	 Total delay: 253.662 	 Acceptance rate: 1.000
# Request 2282 	: Total cost: 160.931 	 Total delay: 291.753 	 Acceptance rate: 1.000
# Request 2283 	: Total cost: 98.943 	 Total delay: 231.005 	 Acceptance rate: 1.000
# Request 2284 	: Total cost: 125.132 	 Total delay: 237.962 	 Acceptance rate: 1.000
# Request 2285 	: Total cost: 95.545 	 Total delay: 191.660 	 Acceptance rate: 1.000
# Request 2286 	: Total cost: 101.610 	 Total delay: 243.355 	 Acceptance rate: 1.000
# Request 2287 	: Total cost: 134.540 	 Total delay: 204.690 	 Acceptance rate: 1.000
# Request 2288 	: Total cost: 98.846 	 Total delay: 240.483 	 Acceptance rate: 1.000
# Request 2289 	: Total cost: 84.594 	 Total delay: 159.913 	 Acceptance rate: 1.000
# Request 2290 	: Total cost: 159.333 	 Total delay: 405.286 	 Acceptance rate: 1.000
# Request 2291 	: Total cost: 123.983 	 Total delay: 266.751 	 Acceptance rate: 1.000
# Request 2292 	: Total cost: 75.858 	 Total delay: 131.463 	 Acceptance rate: 1.000
# Request 2293 	: Total cost: 76.986 	 Total delay: 190.948 	 Acceptance rate: 1.000
# Request 2294 	: Total cost: 102.618 	 Total delay: 271.841 	 Acceptance rate: 1.000
# Request 2295 	: Total cost: 103.844 	 Total delay: 139.717 	 Acceptance rate: 1.000
# Request 2296 	: Total cost: 103.513 	 Total delay: 213.695 	 Acceptance rate: 1.000
# Request 2297 	: Total cost: 116.337 	 Total delay: 225.209 	 Acceptance rate: 1.000
# Request 2298 	: Total cost: 117.202 	 Total delay: 293.492 	 Acceptance rate: 1.000
# Request 2299 	: Total cost: 77.038 	 Total delay: 207.159 	 Acceptance rate: 1.000
# Request 2300 	: Total cost: 62.472 	 Total delay: 63.157 	 Acceptance rate: 1.000
# Request 2301 	: Total cost: 67.048 	 Total delay: 69.409 	 Acceptance rate: 1.000
# Request 2302 	: Total cost: 91.186 	 Total delay: 197.986 	 Acceptance rate: 1.000
# Request 2303 	: Total cost: 123.144 	 Total delay: 297.563 	 Acceptance rate: 1.000
# Request 2304 	: Total cost: 102.033 	 Total delay: 224.872 	 Acceptance rate: 1.000
# Request 2305 	: Total cost: 107.786 	 Total delay: 316.942 	 Acceptance rate: 1.000
# Request 2306 	: Total cost: 125.359 	 Total delay: 323.600 	 Acceptance rate: 1.000
# Request 2307 	: Total cost: 103.291 	 Total delay: 236.765 	 Acceptance rate: 1.000
# Request 2308 	: Total cost: 127.366 	 Total delay: 319.205 	 Acceptance rate: 1.000
# Request 2309 	: Total cost: 117.412 	 Total delay: 302.318 	 Acceptance rate: 1.000
# Request 2310 	: Total cost: 113.013 	 Total delay: 322.669 	 Acceptance rate: 1.000
# Request 2311 	: Total cost: 78.006 	 Total delay: 101.338 	 Acceptance rate: 1.000
# Request 2312 	: Total cost: 127.081 	 Total delay: 394.806 	 Acceptance rate: 1.000
# Request 2313 	: Total cost: 94.607 	 Total delay: 249.639 	 Acceptance rate: 1.000
# Request 2314 	: Total cost: 124.385 	 Total delay: 234.071 	 Acceptance rate: 1.000
# Request 2315 	: Total cost: 96.509 	 Total delay: 199.936 	 Acceptance rate: 1.000
# Request 2316 	: Total cost: 98.346 	 Total delay: 133.794 	 Acceptance rate: 1.000
# Request 2317 	: Total cost: 84.042 	 Total delay: 257.307 	 Acceptance rate: 1.000
# Request 2318 	: Total cost: 148.213 	 Total delay: 288.418 	 Acceptance rate: 1.000
# Request 2319 	: Total cost: 143.657 	 Total delay: 328.647 	 Acceptance rate: 1.000
# Request 2320 	: Total cost: 106.743 	 Total delay: 313.448 	 Acceptance rate: 1.000
# Request 2321 	: Total cost: 103.532 	 Total delay: 158.179 	 Acceptance rate: 1.000
# Request 2322 	: Total cost: 112.048 	 Total delay: 104.299 	 Acceptance rate: 1.000
# Request 2323 	: Total cost: 118.529 	 Total delay: 245.896 	 Acceptance rate: 1.000
# Request 2324 	: Total cost: 95.649 	 Total delay: 282.989 	 Acceptance rate: 1.000
# Request 2325 	: Total cost: 103.279 	 Total delay: 149.783 	 Acceptance rate: 1.000
# Request 2326 	: Total cost: 169.060 	 Total delay: 371.903 	 Acceptance rate: 1.000
# Request 2327 	: Total cost: 82.152 	 Total delay: 145.266 	 Acceptance rate: 1.000
# Request 2328 	: Total cost: 77.689 	 Total delay: 117.440 	 Acceptance rate: 1.000
# Request 2329 	: Total cost: 121.113 	 Total delay: 233.660 	 Acceptance rate: 1.000
# Request 2330 	: Total cost: 140.288 	 Total delay: 244.537 	 Acceptance rate: 1.000
# Request 2331 	: Total cost: 158.654 	 Total delay: 374.761 	 Acceptance rate: 1.000
# Request 2332 	: Total cost: 142.943 	 Total delay: 312.918 	 Acceptance rate: 1.000
# Request 2333 	: Total cost: 92.136 	 Total delay: 194.315 	 Acceptance rate: 1.000
# Request 2334 	: Total cost: 142.239 	 Total delay: 296.627 	 Acceptance rate: 1.000
# Request 2335 	: Total cost: 116.744 	 Total delay: 268.957 	 Acceptance rate: 1.000
# Request 2336 	: Total cost: 102.524 	 Total delay: 236.418 	 Acceptance rate: 1.000
# Request 2337 	: Total cost: 82.957 	 Total delay: 143.980 	 Acceptance rate: 1.000
# Request 2338 	: Total cost: 90.430 	 Total delay: 176.229 	 Acceptance rate: 1.000
# Request 2339 	: Total cost: 67.048 	 Total delay: 58.469 	 Acceptance rate: 1.000
# Request 2340 	: Total cost: 100.112 	 Total delay: 247.198 	 Acceptance rate: 1.000
# Request 2341 	: Total cost: 153.933 	 Total delay: 409.637 	 Acceptance rate: 1.000
# Request 2342 	: Total cost: 183.124 	 Total delay: 294.606 	 Acceptance rate: 1.000
# Request 2343 	: Total cost: 101.683 	 Total delay: 255.357 	 Acceptance rate: 1.000
# Request 2344 	: Total cost: 87.168 	 Total delay: 134.021 	 Acceptance rate: 1.000
# Request 2345 	: Total cost: 69.023 	 Total delay: 106.181 	 Acceptance rate: 1.000
# Request 2346 	: Total cost: 121.365 	 Total delay: 230.845 	 Acceptance rate: 1.000
# Request 2347 	: Total cost: 80.336 	 Total delay: 184.124 	 Acceptance rate: 1.000
# Request 2348 	: Total cost: 95.559 	 Total delay: 121.758 	 Acceptance rate: 1.000
# Request 2349 	: Total cost: 133.659 	 Total delay: 140.048 	 Acceptance rate: 1.000
# Request 2350 	: Total cost: 76.194 	 Total delay: 232.898 	 Acceptance rate: 1.000
# Request 2351 	: Total cost: 140.068 	 Total delay: 264.362 	 Acceptance rate: 1.000
# Request 2352 	: Total cost: 60.157 	 Total delay: 153.112 	 Acceptance rate: 1.000
# Request 2353 	: Total cost: 188.550 	 Total delay: 371.565 	 Acceptance rate: 1.000
# Request 2354 	: Total cost: 95.646 	 Total delay: 214.511 	 Acceptance rate: 1.000
# Request 2355 	: Total cost: 103.100 	 Total delay: 151.843 	 Acceptance rate: 1.000
# Request 2356 	: Total cost: 125.050 	 Total delay: 284.076 	 Acceptance rate: 1.000
# Request 2357 	: Total cost: 127.089 	 Total delay: 194.124 	 Acceptance rate: 1.000
# Request 2358 	: Total cost: 65.678 	 Total delay: 92.151 	 Acceptance rate: 1.000
# Request 2359 	: Total cost: 146.050 	 Total delay: 408.069 	 Acceptance rate: 1.000
# Request 2360 	: Total cost: 152.274 	 Total delay: 404.386 	 Acceptance rate: 1.000
# Request 2361 	: Total cost: 95.052 	 Total delay: 141.206 	 Acceptance rate: 1.000
# Request 2362 	: Total cost: 102.972 	 Total delay: 250.119 	 Acceptance rate: 1.000
# Request 2363 	: Total cost: 76.186 	 Total delay: 145.226 	 Acceptance rate: 1.000
# Request 2364 	: Total cost: 87.092 	 Total delay: 113.867 	 Acceptance rate: 1.000
# Request 2365 	: Total cost: 76.152 	 Total delay: 121.052 	 Acceptance rate: 1.000
# Request 2366 	: Total cost: 72.949 	 Total delay: 194.947 	 Acceptance rate: 1.000
# Request 2367 	: Total cost: 77.654 	 Total delay: 243.136 	 Acceptance rate: 1.000
# Request 2368 	: Total cost: 114.287 	 Total delay: 156.122 	 Acceptance rate: 1.000
# Request 2369 	: Total cost: 79.355 	 Total delay: 112.898 	 Acceptance rate: 1.000
# Request 2370 	: Total cost: 132.089 	 Total delay: 182.119 	 Acceptance rate: 1.000
# Request 2371 	: Total cost: 73.155 	 Total delay: 231.853 	 Acceptance rate: 1.000
# Request 2372 	: Total cost: 74.144 	 Total delay: 104.343 	 Acceptance rate: 1.000
# Request 2373 	: Total cost: 103.961 	 Total delay: 228.122 	 Acceptance rate: 1.000
# Request 2374 	: Total cost: 53.070 	 Total delay: 51.058 	 Acceptance rate: 1.000
# Request 2375 	: Total cost: 85.026 	 Total delay: 172.191 	 Acceptance rate: 1.000
# Request 2376 	: Total cost: 82.324 	 Total delay: 234.700 	 Acceptance rate: 1.000
# Request 2377 	: Total cost: 170.783 	 Total delay: 225.405 	 Acceptance rate: 1.000
# Request 2378 	: Total cost: 138.781 	 Total delay: 345.511 	 Acceptance rate: 1.000
# Request 2379 	: Total cost: 113.845 	 Total delay: 317.124 	 Acceptance rate: 1.000
# Request 2380 	: Total cost: 81.815 	 Total delay: 152.510 	 Acceptance rate: 1.000
# Request 2381 	: Total cost: 167.458 	 Total delay: 270.604 	 Acceptance rate: 1.000
# Request 2382 	: Total cost: 88.302 	 Total delay: 172.528 	 Acceptance rate: 1.000
# Request 2383 	: Total cost: 85.847 	 Total delay: 193.202 	 Acceptance rate: 1.000
# Request 2384 	: Total cost: 106.951 	 Total delay: 400.698 	 Acceptance rate: 1.000
# Request 2385 	: Total cost: 95.545 	 Total delay: 136.365 	 Acceptance rate: 1.000
# Request 2386 	: Total cost: 125.409 	 Total delay: 355.861 	 Acceptance rate: 1.000
# Request 2387 	: Total cost: 114.973 	 Total delay: 138.622 	 Acceptance rate: 1.000
# Request 2388 	: Total cost: 109.191 	 Total delay: 294.739 	 Acceptance rate: 1.000
# Request 2389 	: Total cost: 95.266 	 Total delay: 147.495 	 Acceptance rate: 1.000
# Request 2390 	: Total cost: 61.839 	 Total delay: 130.620 	 Acceptance rate: 1.000
# Request 2391 	: Total cost: 113.581 	 Total delay: 240.968 	 Acceptance rate: 1.000
# Request 2392 	: Total cost: 114.114 	 Total delay: 156.886 	 Acceptance rate: 1.000
# Request 2393 	: Total cost: 84.245 	 Total delay: 228.585 	 Acceptance rate: 1.000
# Request 2394 	: Total cost: 67.756 	 Total delay: 106.554 	 Acceptance rate: 1.000
# Request 2395 	: Total cost: 123.694 	 Total delay: 461.581 	 Acceptance rate: 1.000
# Request 2396 	: Total cost: 125.689 	 Total delay: 277.643 	 Acceptance rate: 1.000
# Request 2397 	: Total cost: 69.204 	 Total delay: 136.881 	 Acceptance rate: 1.000
# Request 2398 	: Total cost: 53.524 	 Total delay: 97.027 	 Acceptance rate: 1.000
# Request 2399 	: Total cost: 86.867 	 Total delay: 122.469 	 Acceptance rate: 1.000
# Request 2400 	: Total cost: 105.472 	 Total delay: 375.518 	 Acceptance rate: 1.000
# Request 2401 	: Total cost: 105.410 	 Total delay: 165.494 	 Acceptance rate: 1.000
# Request 2402 	: Total cost: 61.610 	 Total delay: 76.827 	 Acceptance rate: 1.000
# Request 2403 	: Total cost: 110.158 	 Total delay: 144.870 	 Acceptance rate: 1.000
# Request 2404 	: Total cost: 92.619 	 Total delay: 194.582 	 Acceptance rate: 1.000
# Request 2405 	: Total cost: 126.711 	 Total delay: 221.098 	 Acceptance rate: 1.000
# Request 2406 	: Total cost: 94.264 	 Total delay: 231.249 	 Acceptance rate: 1.000
# Request 2407 	: Total cost: 127.677 	 Total delay: 279.956 	 Acceptance rate: 1.000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 26
#      18 total_request += 1
#      20 v_network = VirtualNetwork.generator(
#      21                 num_nodes=number_of_request_nodes,
#      22                 connection_rate=0.5,
#      23                 number_of_domains=number_of_physical_network_domain
#      24             )
# ---> 26 best_mapping = mpvne.run(v_network)
#      27 if not best_mapping:
#      28     reason[0] += 1
#
# Cell In[13], line 203, in MP_VNE.run(self, v_network)
#     200 if [] in candidate_nodes:
#     201     return None
# --> 203 best_mapping = self.optimize_mapping(v_network, candidate_nodes, 50)
#     204 self.map(v_network, best_mapping)
#     205 return best_mapping
#
# Cell In[13], line 135, in MP_VNE.optimize_mapping(self, v_network, candidate_nodes, num_particles, max_iter)
#     132 v = v + (c1 * r1 * diff_local) + (c2 * r2 * diff_global)
#     134 for i in range(num_particles):
# --> 135     particles[i] = MP_VNE.add_operation(particles[i], v[i])
#     136     for j in range(num_v_nodes):
#     137         particles[i][j] = particles[i][j] % len(candidate_nodes[j])
#
# Cell In[13], line 96, in MP_VNE.add_operation(a, b)
#      92     arr_b = np.array(b)
#      94     return (arr_a != arr_b).astype(int)
# ---> 96 @staticmethod
#      97 def add_operation(a, b):
#      98     return a + b
#     100 def optimize_mapping(self, v_network: VirtualNetwork, candidate_nodes: List[List[PhysicalNode]], num_particles=10, max_iter=30) -> List[PhysicalNode]:
#
# KeyboardInterrupt:

# %%
visualize_array(costs, "Mapping Cost", "Time", "Cost")
visualize_array(delays, "Mapping Delay", "Time", "Delay")
visualize_array(acceptance_rates, "Acceptance Rate", "Time", "Rate")

# %%
print(reason)
# Out:
# [0, 0, 0]
